# %%
from seleniumrequests import Firefox
from bs4 import BeautifulSoup
webdriver.implicitly_wait(10)
webdriver = Firefox()
response = webdriver.request('get','http://www.appledaily.com.tw/realtimenews/article/property/20151027/720171/applesearch/%E9%9B%99%E5%B1%A4%E5%BA%97%E9%9D%A2%E5%A4%AF%E3%80%80%E5%8C%97%E5%B8%82%E5%83%B9%E6%A0%BC%E5%B9%B4%E6%BC%B2%E8%BF%912%E6%88%90')
soup = BeautifulSoup(response.text)
print soup

# %%
soup.select('.pluginCountTextDisconnected')

# %%
driver = webdriver.Chrome(executable_path=r"E:\\hunterking3305\\crawler\\chromedriver\\chromedriver.exe")

# %%
driver.get('http://news.ltn.com.tw/news/focus/paper/928123')

# %%
res_text = driver.page_source

# %%
print res_text
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head>
# <base href="http://news.ltn.com.tw" />
# <meta charset="utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=10; IE=9; IE=8; IE=7" />
# <title>轟馬3施政 看看朱過去怎麼說… - 焦點 - 自由時報電子報</title>
# <meta name="google-site-verification" content="sPp7Kk7Tqa6LK-wWblS9Fby069Wpy4DNTaMyjKHxveU" />
# <meta name="description" content="國民黨總統參選人朱立倫連兩日大動作就課徵證所稅、十二年國教及油電雙漲等馬政府執政的三項政策提出批評，被外界形容與馬切割。不過回顧其以往之言行，除涉及地方行政的十二年國教，朱曾聯合台北市力抗教育部外，他只在電價確定分段調漲後才要求台電應先改革再談漲價。至於證所稅，他則支持企業將逐步課徵的賦改會決議。由於十二年國教直接涉及地方行政，朱立倫在二○一三年六月，就基於財政立場，「郝立強」三人合體反對「中央請客，地方買單」，要求排富。朱強調，若一開始不排富，再想排富就很難，新北市將因全面免學費多支出十三億元。教育部因此退讓，訂出家戶年所得一四八萬元的排富門檻。" />
# <meta name="keywords" content="自由時報, 自由電子報, 自由時報電子報, Liberty Times Net, LTN" />
# <meta name="robots" content="index,follow" />
# <meta property="fb:app_id" content="140490219413038" />
# <meta property="og:title" content="轟馬3施政 看看朱過去怎麼說… - 焦點 - 自由時報電子報" />
# <meta property="og:type" content="article" />
# ...

# %%
import requests 

res = requests.get('http://news.ltn.com.tw/news/focus/paper/928123')

# %%
print res.text
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
#
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8">
#   <title>東區店面3億成交　區域近1年新高 | 即時新聞 | 20151029 | 蘋果日報</title>
#   <meta name="Title" content="東區店面3億成交區域近1年新高 | 即時新聞 | 20151029 | 蘋果日報" />
#   <meta name="description" content="今年台北市住宅交易冷清，但東區茶街7月仍有店面成交總價高達3億元，刷新了大安區近1年店面總價新高紀錄！&nbsp;去年下半年開始，房市景氣一路滑落，連熱鬧的東區近來也不少店面待租、空置中，但忠孝東路四"/>
#   <meta name="keywords" content=",地產,property,蘋果日報,地產新聞,apple daily,台灣,爽報,壹週刊,壹電視,動新聞,即時新聞,影音新聞" />
#   <meta name="Robots" content="INDEX,FOLLOW" />
#   <meta property="fb:admins" content="100003491041452"/>
#   <meta property="fb:app_id" content="244889285591923"/>
#   <meta name="twitter:card" content="summary_large_image" />
# ...

# %%
from bs4 import BeautifulSoup as bs
soup= bs(res.text)
# Out:
# c:\python27\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
maa = soup.select('.function_icon.clicked')[0].text

# %%
import re

# %%
m = re.search('(\d+)',maa)

# %%
print m.group(1)
# Out:
# 3995

# %%
import requests
res = requests.get('http://www.appledaily.com.tw/realtimenews/article/finance/20151030/722521/applesearch/%E3%80%90%E7%A7%91%E6%8A%80%E6%96%B0%E5%A0%B1%E3%80%91%E6%99%BA%E6%85%A7%E7%AF%80%E9%9B%BB%E9%BB%91%E5%AE%A2%E6%9D%BE%E7%AB%B6%E8%B3%BD%EF%BC%8C%E6%B7%B1%E5%85%A5%E7%A4%BE%E5%8D%80%E8%92%90%E9%9B%86%E7%AF%80%E8%83%BD%E7%B6%93%E9%A9%97')
res.text
# Out:
# u'<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->\n<!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->\n<!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->\n<!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->\n\n<head>\n  <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n  <title>\u3010\u79d1\u6280\u65b0\u5831\u3011\u667a\u6167\u7bc0\u96fb\u9ed1\u5ba2\u677e\u7af6\u8cfd\uff0c\u6df1\u5165\u793e\u5340\u8490\u96c6\u7bc0\u80fd\u7d93\u9a57 | \u5373\u6642\u65b0\u805e | 20151030 | \u860b\u679c\u65e5\u5831</title>\n  <meta name="Title" content="\u3010\u79d1\u6280\u65b0\u5831\u3011\u667a\u6167\u7bc0\u96fb\u9ed1\u5ba2\u677e\u7af6\u8cfd\uff0c\u6df1\u5165\u793e\u5340\u8490\u96c6\u7bc0\u80fd\u7d93\u9a57 | \u5373\u6642\u65b0\u805e | 20151030 | \u860b\u679c\u65e5\u5831" />\n  <meta name="description" content="\u672c\u5167\u5bb9\u7531\u79d1\u6280\u65b0\u5831TechNews\u63d0\u4f9b\u70ba\u4e86\u97ff\u
# ...

# %%
from bs4 import BeautifulSoup
import re
soup = BeautifulSoup(res.text)

reele = soup.select('.urcc a')[0].text

# %%
rdrx = re.search('(\d+)',reele)

# %%
print rdrx.group(1)
# Out:
# 248
