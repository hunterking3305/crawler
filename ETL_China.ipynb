# %% [markdown]
# #----------------------start from here-----------------------

# %%
def getinfo(soup):
    for bid in soup.select('.gsc-table-cell-thumbnail .gs-title'):
        if bid.get('href') is not None:
            str_bid = str(bid.get('href'))
            if 'newspapers' in str_bid:
                print str_bid
        res2 = requests.get(str_bid)
        soup2 = BeautifulSoup(res2.text)
        res2.close()
        text = ""
        for p_tag in soup2.select('article p'):
            text = text + p_tag.text.strip()
        h1_tag = soup2.select('article header h1')[0].text
        if h1_tag is None:
            title = ""
        title = h1_tag
        pan_ary.append({
        "area":area,
        "links":str_bid,
        "title":title,
        "time":soup2.select('time')[0]['datetime'],
        "content":text
        })            
            
#             print ele.select('h1')[0].text
#             print ele.select('time')[0]['datetime']
#             for p_tag in ele.select('p'):
#                 print p_tag.text

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

ary = ['中正區']    #12個行政區
pan_ary = []#建字典
for area in ary:
    for page in range(1,2):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        headers = {
            'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Encoding':'gzip, deflate, sdch',
            'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
            'Connection':'keep-alive',
            'Host':'www.chinatimes.com',
            'Referer':page_url,
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'
        }
        getinfo(soup)
driver.close()
df = pandas.Dataframe(pan_ary)
df

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from seleniumrequests import Firefox
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

#12個行政區
ary = ['中正區'] 
#建字典
pan_ary = []
for area in ary:
    for page in range(1,3):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        for bid in soup.select('.gs-bidi-start-align gs-visibleUrl gs-visibleUrl-long')[0].text:
            print bid

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from seleniumrequests import Firefox
import requests
import time
import pandas

page_url = "http://www.chinatimes.com/search/result.htm?q="+ '中正區'
driver.get(page_url)
res_text = driver.page_source

# %%
from bs4 import BeautifulSoup as bs
soup =  bs(res_text)

# %%
for a in soup.select('.gs-per-result-labels'):
    if a.get('url') is not None:
        print a.get('url')

# %%
ary = ['中正區','中山區','松山區'] 
for area in ary:
    print area

# %% [markdown]
# ------------------------------------2015/10/29------------------------------------(The Latest One)

# %%
#編制 PK
def getpk(arry):
    global pk
    for elelink in arry:
        num = str(pkcount)
        if pkcount < 10:
            num = str(0) * 4 + num
        elif pkcount < 100:     
            num = str(0) * 3 + num
        elif pkcount < 1000:     
            num = str(0) * 2 + num
        elif pkcount < 10000:     
            num = str(0) * 1 + num
        pk = cht + num
        links = {'link':'','area':area,'page':page,'count':count,'pk':pk}

# %%
#儲存文章連結 用來建立連結資料
from bs4 import BeautifulSoup
def getlinkv2(script):
    global arry, pkcount, cht, pk  #global arry ,pkcount, cht
    global count
    arry = []  #arry = []
    cht = 'cht'   # cht = 'cht'
    soup = BeautifulSoup(script)
    for link_tag in soup.select('.gs-per-result-labels'):
        if link_tag.get('url') is not None:
            if 'realtimenews' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                arry.append(link)   #arry.append(link)
                getpk(arry)             #getpk()
                links = {'link':link,'area':area,'page':page,'count':count,'pk':pk}  #,'pk':pk
                linkary.append(links)
                count +=1
                pkcount += 1    #pkcount += 1
            elif 'newspaper' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                arry.append(link)   #arry.append(link)
                getpk(arry)             #getpk()
                links = {'link':link,'area':area,'page':page,'count':count,'pk':pk}  #,'pk':pk
                linkary.append(links)
                count +=1
                pkcount += 1    #pkcount += 1

# %%
from selenium import webdriver
import requests
import time

#列出所需查詢區域 一開始先測試3區的效果
#['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
ary = ['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
links = {'link':'','area':'','page':'','count':''}
linkary =[]

driver = webdriver.Firefox()
driver.implicitly_wait(30)

#每一區
pkcount = 1    #pkcount = 1
for area in ary:
    count = 1
#每一頁
    for page in range(1,9):
        if page == 1:
            url_format = 'http://www.chinatimes.com/search/result.htm?q=' + area + '#gsc.tab=0&gsc.q=' + area\
                         + '&gsc.sort=date&gsc.page={}'.format(page)
# url_format = 'http://www.chinatimes.com/search/result.htm?q='+area+'#gsc.tab=0&gsc.q='+area+'&gsc.page={}'.format(page)
            try:
                driver.get(url_format)
                driver.implicitly_wait(30)
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
                driver.implicitly_wait(30)
            except:
                time.sleep(5)
                continue
        else:
            try:
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
                driver.implicitly_wait(30)
            except:
                time.sleep(5)
                continue
                
        time.sleep(3) #避免讓伺服器察覺攻擊
        script = res_text
        getlinkv2(script)

# %%
#將新聞連結變成DataFrame
import pandas
data1 = pandas.DataFrame(linkary)
data1
# Out:
#     area  count                                               link  page  \
# 0    中正區      1  http://www.chinatimes.com/realtimenews/2015110...     1
# 1    中正區      2  http://www.chinatimes.com/realtimenews/2015110...     1
# 2    中正區      3  http://www.chinatimes.com/realtimenews/2015110...     1
# 3    中正區      4  http://www.chinatimes.com/newspapers/201511030...     1
# 4    中正區      5  http://www.chinatimes.com/realtimenews/2015110...     1
# 5    中正區      6  http://www.chinatimes.com/realtimenews/2015110...     1
# 6    中正區      7  http://www.chinatimes.com/newspapers/201511030...     1
# 7    中正區      8  http://www.chinatimes.com/realtimenews/2015103...     1
# 8    中正區      9  http://www.chinatimes.com/realtimenews/2015103...     2
# 9    中正區     10  http://www.chinatimes.com/realtimenews/2015103...     2
# 10   中正區     11  http://www.chinatimes.com/realtimenews/2015103...     2
# 11   中正區     12  http://www.chinatimes.com/realtimenews/2015102...     2
# 12   中正區     13  http://www.chinatimes.com/newspapers/201510280...     3
# 13   中正區     14  http://www.chinatimes.com/realtimenews/2015102...     3
# 14   中正區     15  http://www.chinatimes.com/realtimenews/2015102...     3
# 15   中正區     16  http://www.chinatimes.com/newspapers/201510260...     3
# 16   中正區     17  http://www.chinatimes.com/newspapers/201510260...     3
# 17   中正區     18  http://www.chinatimes.com/realtimenews/2015102...     3
# 18   中正區     19  http://www.chinatimes.com/newspapers/201510250...     3
# 19   中正區     20  http://www.chinatimes.com/newspapers/201510250...     3
# 20   中正區     21  http://www.chinatimes.com/realtimenews/2015102...     4
# 23   cht00024
# 24   cht00025
# 25   cht00026
# 26   cht00027
# 27   cht00028
# 28   cht00029
# 29   cht00030
# ..        ...
# 501  cht00502
# 502  cht00503
# 503  cht00504
# 504  cht00505
# 505  cht00506
# 506  cht00507
# 507  cht00508
# 508  cht00509
# 509  cht00510
# 510  cht00511
# 511  cht00512
# 512  cht00513
# 513  cht00514
# 514  cht00515
# 515  cht00516
# 516  cht00517
# 517  cht00518
# 518  cht00519
# 519  cht00520
# 520  cht00521
# 521  cht00522
# 522  cht00523
# 523  cht00524
# 524  cht00525
# 525  cht00526
# 526  cht00527
# 527  cht00528
# 528  cht00529
# 529  cht00530
# 530  cht00531
#
# [531 rows x 5 columns]

# %%
#輸出成CSV檔將連結存起
data1.to_csv('cht_link.csv',encode='utf-8')

# %%
#讀入CSV
import csv
linkary = []
with open('cht_link.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        linkary.append(row)

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import time

for get in linkary:
    headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
    }
    text = ''
    while True:
        try:
            url = get['link']
            res = requests.get(url, headers = headers)
            soup = BeautifulSoup(res.text)
            break
        except:
            time.sleep(5)
#----------------------------------------------------------------------------------------------    
    try:
        get['title'] = soup.select('.clear-fix h1')[0].text
#             print get['title']
        get['date'] = soup.select('.clear-fix time')[0]['datetime']
#             print get['time']
        get['like'] = soup.select('.clear-fix .num')[0].text
#             print get['like']
        for p_tag in soup.select('.clear-fix article p'):
            text += p_tag.text.strip()
        get['content'] = text
#             print get['content']
    except:
        print "This link has some problems!"
        print get['link'], get['area'], get['count']
# Out:
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 士林區 27
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 內湖區 7
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 南港區 29
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 文山區 34

# %%
#輸出成檔案
import pandas
data2 = pandas.DataFrame(linkary)

#刪除多餘的欄位
cht_ok = data2.drop(data2.columns[[0]],axis=1)
cht_ok
# Out:
#     area                                            content count  \
# 0    中正區  「一朝天子一朝臣、不得志不如歸去！」中市政黨輪替後，台中市國中小學爆發校長及老師退休潮，今年...     1
# 1    中正區  27歲的胡姓男子上月31日清晨5時許，與從三峽來的林男和綽號翁肥的男子在泰山會合，但他嫌63...     2
# 2    中正區  台北市30多歲林姓男子，今年8月走在中山區某路騎樓看見一雙黑色高跟鞋，竟順手牽羊偷走，警方調...     3
# 3    中正區  苗栗縣銅鑼鄉九湖杭菊陸續盛開，但今年先後慘遭蘇迪勒及杜鵑颱風摧殘，災損嚴重，網路上甚至出現建...     4
# 4    中正區  2015年高雄市特教生藝術創作聯展2日在佛光山展出，38位身心障礙學生的百件水彩畫、油畫、版...     5
# 5    中正區  新北市中和區公所與議員陳錦錠服務處合作，在中和區前國防管理學院中正堂及操場舉辦「中和．遇見愛...     6
# 6    中正區  近年來國際金融市場波動頻繁，尤其是在2008年國際金融海嘯及2009年歐洲主權債務危機發生後...     7
# 7    中正區  連辦6年的玩家模型展今年終於跨出第一步，全台60多位模型師打造的188件作品31日受邀至台南...     8
# 8    中正區  連辦6年的玩家模型展今年終於跨出第一步，全台60多位模型師打造的188件作品31日受邀至台南...     9
# 9    中正區  親民黨總統參選人宋楚瑜，31日晚間在高雄市苓雅區武昌路成立南部競選總部，他開口問「總部設在武...    10
# 529  http://www.chinatimes.com/newspapers/201510140...    7  cht00530
# 530  http://www.chinatimes.com/realtimenews/2015101...    7  cht00531
#
#                       title
# 0        政治介入台中校園 老師校長退休潮湧現
# 1        嫌車資太貴 3男痛毆計程車司機後搶錢
# 2            愛偷穿過女高跟鞋 變態男被訴
# 3        雙颱摧殘仍綻美景 銅鑼杭菊已白雪覆地
# 4          高雄特教生藝術創作展 佛光山登場
# 5            中和遇見愛！ 人生幸福的起點
# 6          掌握亞洲金融脈動 江丙坤學術講座
# 7         玩家模型展 台南新光三越中山店登場
# 8         玩家模型展 台南新光三越中山店登場
# 9      宋楚瑜南部競選總部成立 高喊「武昌起義」
# 10           監守自盜鎳粉 康普2員工送辦
# 11    強風掀翻桃機僅剩跑道柏油路面 班機大排長龍
# 12           基隆中正高架橋 貨櫃車又偷跑
# 13   《傳產》國產署設定地上權招標冷清，僅2宗脫標
# 14       博愛特區兆豐銀驚傳搶案 打傷保全逃逸
# 15            台省城隍廟遶境 陸客搶拍照
# 16           文創中介經紀論壇 28日登場
# 17           省城隍廟遶境 2500人參與
# 18           兩岸史話－兩岸二戰時不是敵國
# 19             同學牽盲生賽跑 感動全場
# 20           省城隍廟遶境 2500人參與
# 21           兩岸史話－兩岸二戰時不是敵國
# 22             同學牽盲生賽跑 感動全場
# 23           兩岸史話－兩岸二戰時不是敵國
# 24            時論－蔡英文思想錯亂的根源
# 25             台北市605個路段飲鉛水
# 26       黑豹旗64強中正高中被逆轉 球員痛哭
# 27              釀酒師返鄉打造葡萄酒區
# 28             提高癌篩率 小小兵出任務
# 29          女街友乳癌胸長千蛆 嚇壞消防員
# ..                      ...
# 501             臺北詩歌節 替靈魂打氣
# 502         郁慕明批李慶元 沒新黨哪有今天
# 503          馬總統出席 警專70週年校慶
# 504            扯鈴小將出征 義賣籌旅費
# 505              柯P：打房≠居住正義
# 506         親子聯歡防災宣導 強化社區安全
# 507        HBL資格賽 木柵高工獲甲級首勝
# 508           夜夜夢冤魂 頂罪男供出真凶
# 509          靈骨塔業務兼販毒 開毒趴被逮
# 510       《桃園三結義》 裴艷玲跨行當演張飛
# 511            台北市605個路段飲鉛水
# 512           知名夜市、商圈中標：快換管
# 513            幸福學院揭牌 祖孫同學樂
# 514          陪祖孫過重陽 柯：拓育兒據點
# 515     陸京劇裴豔玲大師來台演出「桃園三結義」
# 516       裴豔玲大師來台 演出「桃園三結義」
# 517         總統盃慢壘賽 夏綠地稱霸公開組
# 518             台北人購屋比 六都最低
# 519             竹塹漫談－打造兒童城市
# 520      北市房市納涼 每100戶不到2戶購屋
# 521         建商減量保價 北市新屋供給腰斬
# 522         政大野火陣線不滿校歌 校園噴漆
# 523         基隆／台北治理經驗替基隆謀福利
# 524          逾60歲 可在社區打流感疫苗
# 525                     NaN
# 526           大台北人口紅利區 內湖居首
# 527        《產業》百家爭鳴，太陽光電展登場
# 528       補充保費門檻 曾銘宗：調高有益散戶
# 529      不滿行動派出所 王世堅：要推倒質詢台
# 530        警專生跑步訓練昏倒 送醫救回一命
#
# [531 rows x 9 columns]

# %%
cht_ok.to_csv('cht_ok.csv',encoding='utf-8')
