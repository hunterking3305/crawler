# %% [markdown]
# #----------------------start from here-----------------------

# %%
def getinfo(soup):
    for bid in soup.select('.gsc-table-cell-thumbnail .gs-title'):
        if bid.get('href') is not None:
            str_bid = str(bid.get('href'))
            if 'newspapers' in str_bid:
                print str_bid
        res2 = requests.get(str_bid)
        soup2 = BeautifulSoup(res2.text)
        res2.close()
        text = ""
        for p_tag in soup2.select('article p'):
            text = text + p_tag.text.strip()
        h1_tag = soup2.select('article header h1')[0].text
        if h1_tag is None:
            title = ""
        title = h1_tag
        pan_ary.append({
        "area":area,
        "links":str_bid,
        "title":title,
        "time":soup2.select('time')[0]['datetime'],
        "content":text
        })            
            
#             print ele.select('h1')[0].text
#             print ele.select('time')[0]['datetime']
#             for p_tag in ele.select('p'):
#                 print p_tag.text

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

ary = ['中正區']    #12個行政區
pan_ary = []#建字典
for area in ary:
    for page in range(1,2):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        headers = {
            'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Encoding':'gzip, deflate, sdch',
            'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
            'Connection':'keep-alive',
            'Host':'www.chinatimes.com',
            'Referer':page_url,
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'
        }
        getinfo(soup)
driver.close()
df = pandas.Dataframe(pan_ary)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-0fe1840fe8c5> in <module>()
#      33             'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'
#      34         }
# ---> 35         getinfo(soup)
#      36 driver.close()
#      37 df = pandas.Dataframe(pan_ary)
#
# <ipython-input-8-7dc73d973e3f> in getinfo(soup)
#      11         for p_tag in soup2.select('article p'):
#      12             text = text + p_tag.text.strip()
# ---> 13         h1_tag = soup2.select('article header h1')[0].text
#      14         if h1_tag is None:
#      15             title = ""
#
# IndexError: list index out of range

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from seleniumrequests import Firefox
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

#12個行政區
ary = ['中正區'] 
#建字典
pan_ary = []
for area in ary:
    for page in range(1,3):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        for bid in soup.select('.gs-bidi-start-align gs-visibleUrl gs-visibleUrl-long')[0].text:
            print bid
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-e66aa25f9278> in <module>()
#      25             soup = BeautifulSoup(res_text)
#      26             driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
# ---> 27         for bid in soup.select('.gs-bidi-start-align gs-visibleUrl gs-visibleUrl-long')[0].text:
#      28             print bid
#
# IndexError: list index out of range

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from seleniumrequests import Firefox
import requests
import time
import pandas

page_url = "http://www.chinatimes.com/search/result.htm?q="+ '中正區'
driver.get(page_url)
res_text = driver.page_source

# %%
from bs4 import BeautifulSoup as bs
soup =  bs(res_text)

# %%
for a in soup.select('.gs-per-result-labels'):
    if a.get('url') is not None:
        print a.get('url')
# Out:
# http://www.chinatimes.com/reporter/138
# http://www.chinatimes.com/vote/municipalmayors/county/100
# http://www.chinatimes.com/realtimenews/20150526004435-260402
# http://www.chinatimes.com/newspapers/20150513000138-260204
# http://www.chinatimes.com/vote/chiefofvillage/elected
# http://www.chinatimes.com/reporter/349
# http://tube.chinatimes.com/20151022003828-261403
# http://www.chinatimes.com/realtimenews/20150609002787-260410
# http://www.chinatimes.com/newspapers/20150917000470-260102
# http://tube.chinatimes.com/ctv
# http://www.chinatimes.com/realtimenews/20150522004937-260402
# http://magazine.chinatimes.com/housefun/20150714002517-300505

# %%
ary = ['中正區','中山區','松山區'] 
for area in ary:
    print area
# Out:
# 中正區
# 中山區
# 松山區

# %%
print "--------------------------------------------------------------------------------------------------------------------------"
# Out:
# --------------------------------------------------------------------------------------------------------------------------

# %%
#儲存文章連結 用來建立連結資料
from bs4 import BeautifulSoup
def getlinkv2(script):
    global count
    soup = BeautifulSoup(script)
    for link_tag in soup.select('.gs-per-result-labels'):
        if link_tag.get('url') is not None:
            if 'realtimenews' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                links = {'link':link,'area':area,'page':page,'count':count}
                linkary.append(links)
                count +=1
            elif 'newspaper' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                links = {'link':link,'area':area,'page':page,'count':count}
                linkary.append(links)
                count +=1

# %%
from selenium import webdriver
import requests
import time

#列出所需查詢區域 一開始先測試3區的效果
#['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
ary = ['中正區','大同區']
links = {'link':'','area':'','page':'','count':''}
linkary =[]

driver = webdriver.Firefox()
driver.implicitly_wait(30)
#每一區
for area in ary:
    count = 1
#每一頁
    for page in range(1,3):
        if page == 1:
            url_format = 'http://www.chinatimes.com/search/result.htm?q='+area+'#gsc.tab=0&gsc.q='+area \
                         +'&gsc.page={}'.format(page)
            try:
                driver.get(url_format)
                driver.implicitly_wait(30)
                driver.find_element_by_css_selector("div.gsc-option-selector").click()
                driver.find_element_by_css_selector("div.gsc-option").click()
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
            except:
                time.sleep(5)
                continue
        else:
            try:
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
            except:
                time.sleep(5)
                continue
                
        time.sleep(3) #避免讓伺服器察覺攻擊
        script = res_text
        getlinkv2(script)
# Out:
# c:\python27\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
import pandas
data1 = pandas.DataFrame(linkary)

# %%
#輸出成CSV檔將連結存起
# data1.to_csv('news_link.csv',encode='utf-8')

#讀入CSV
import csv
linkary = []
with open('news_link.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        linkary.append(row)

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import time

text = ''
for get in linkary:
    headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
    }
    while True:
        try:
            url = get['link']
            res = requests.get(url, headers = headers)
            soup = BeautifulSoup(res.text)
            break
        except:
            time.sleep(5)
    try:
        get['title'] = soup.select('.clear-fix h1')[0].text
#         print get['title']
        get['time'] = soup.select('.clear-fix time')[0]['datetime']
#         print get['time']
        get['like'] = soup.select('.clear-fix .num')[0].text
#         print get['like']
        for p_tag in soup.select('.clear-fix article p'):
            text += p_tag.text.strip()
        get['content'] = text
#         print get['content']
    except:
        print "This link has some problems!"
        print get['link'], get['area'], get['count']

# %%
#輸出成檔案
import pandas
data2 = pandas.DataFrame(linkary)
data2
# data2.to_csv('ok.csv',encode='utf-8')
# Out:
#        area                                            content count   like  \
# 0    0  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     1    145
# 1    1  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     2    562
# 2    2  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     3   2819
# 3    3  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     4    393
# 4    4  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     5  25148
# 5    5  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     6    145
# 6    6  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     7   1873
# 7    7  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     8   2914
# 8    8  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     9    903
# 9    9  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    10     94
# 10  10  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    11   1667
# 11  11  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    12    310
# 12  12  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    13  52118
# 13  13  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    14   2706
# 14  14  中正區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    15   2276
# 15  15  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     1   4849
# 16  16  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     2    608
# 17  17  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     3    830
# 18  18  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     4  42113
# 19  19  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     5    999
# 20  20  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     6   2498
# 21  21  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     7    472
# 22  22  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     8  42642
# 23  23  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...     9  40948
# 24  24  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    10   1007
# 25  25  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    11   3960
# 26  26  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    12     72
# 27  27  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    13    290
# 28  28  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    14   1904
# 29  29  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    15    872
# 30  30  大同區  店面租金雖跌，但是「1+2樓雙層店面」行情卻好的很。根據最新統計，北市若一、二樓一起「雙層出...    16    593
#
#                                                  link page              time  \
# 0   http://www.chinatimes.com/realtimenews/2015102...    1  2015/10/27 00:00
# 1   http://www.chinatimes.com/realtimenews/2015102...    1  2015/10/27 00:00
# 2   http://www.chinatimes.com/realtimenews/2015102...    1  2015/10/27 00:00
# 3   http://www.chinatimes.com/newspapers/201510270...    1  2015/10/27 00:00
# 4   http://www.chinatimes.com/realtimenews/2015102...    1  2015/10/26 00:00
# 5   http://www.chinatimes.com/cn/realtimenews/2015...    1  2015/10/27 00:00
# 6   http://www.chinatimes.com/newspapers/201510270...    1  2015/10/27 00:00
# 7   http://www.chinatimes.com/cn/realtimenews/2015...    1  2015/10/27 00:00
# 8   http://www.chinatimes.com/newspapers/201510260...    2  2015/10/26 00:00
