# %% [markdown]
# #----------------------start from here-----------------------

# %%
def getinfo(soup):
    for bid in soup.select('.gsc-table-cell-thumbnail .gs-title'):
        if bid.get('href') is not None:
            str_bid = str(bid.get('href'))
            if 'newspapers' in str_bid:
                print str_bid
        res2 = requests.get(str_bid)
        soup2 = BeautifulSoup(res2.text)
        res2.close()
        text = ""
        for p_tag in soup2.select('article p'):
            text = text + p_tag.text.strip()
        h1_tag = soup2.select('article header h1')[0].text
        if h1_tag is None:
            title = ""
        title = h1_tag
        pan_ary.append({
        "area":area,
        "links":str_bid,
        "title":title,
        "time":soup2.select('time')[0]['datetime'],
        "content":text
        })            
            
#             print ele.select('h1')[0].text
#             print ele.select('time')[0]['datetime']
#             for p_tag in ele.select('p'):
#                 print p_tag.text

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

ary = ['中正區']    #12個行政區
pan_ary = []#建字典
for area in ary:
    for page in range(1,2):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        headers = {
            'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Encoding':'gzip, deflate, sdch',
            'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
            'Connection':'keep-alive',
            'Host':'www.chinatimes.com',
            'Referer':page_url,
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/45.0.2454.101 Safari/537.36'
        }
        getinfo(soup)
driver.close()
df = pandas.Dataframe(pan_ary)
df

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from seleniumrequests import Firefox
import requests
import time
import pandas

driver = webdriver.Firefox()
driver.implicitly_wait(30)

#12個行政區
ary = ['中正區'] 
#建字典
pan_ary = []
for area in ary:
    for page in range(1,3):    #ex:1頁 ==> (1,2)
        if page == 1:
            page_url = "http://www.chinatimes.com/search/result.htm?q="+ area
            driver.get(page_url)
            driver.find_element_by_css_selector("div.gsc-option-selector").click()
            driver.find_element_by_css_selector("div.gsc-option").click()
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        else:
            res_text = driver.page_source
            soup = BeautifulSoup(res_text)
            driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
        for bid in soup.select('.gs-bidi-start-align gs-visibleUrl gs-visibleUrl-long')[0].text:
            print bid

# %%
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from seleniumrequests import Firefox
import requests
import time
import pandas

page_url = "http://www.chinatimes.com/search/result.htm?q="+ '中正區'
driver.get(page_url)
res_text = driver.page_source

# %%
from bs4 import BeautifulSoup as bs
soup =  bs(res_text)

# %%
for a in soup.select('.gs-per-result-labels'):
    if a.get('url') is not None:
        print a.get('url')

# %%
ary = ['中正區','中山區','松山區'] 
for area in ary:
    print area

# %% [markdown]
# ------------------------------------2015/10/29------------------------------------(The Latest One)

# %%
#儲存文章連結 用來建立連結資料
from bs4 import BeautifulSoup
def getlinkv2(script):
    global count
    soup = BeautifulSoup(script)
    for link_tag in soup.select('.gs-per-result-labels'):
        if link_tag.get('url') is not None:
            if 'realtimenews' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                links = {'link':link,'area':area,'page':page,'count':count}
                linkary.append(links)
                count +=1
            elif 'newspaper' in str(link_tag.get('url')):
                link = str(link_tag.get('url'))
                links = {'link':link,'area':area,'page':page,'count':count}
                linkary.append(links)
                count +=1

# %%
from selenium import webdriver
import requests
import time

#列出所需查詢區域 一開始先測試3區的效果
#['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
ary = ['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
links = {'link':'','area':'','page':'','count':''}
linkary =[]

driver = webdriver.Firefox()
driver.implicitly_wait(30)
#每一區
for area in ary:
    count = 1
#每一頁
    for page in range(1,9):
        if page == 1:
            url_format = 'http://www.chinatimes.com/search/result.htm?q=' + area + '#gsc.tab=0&gsc.q=' + area\
                         + '&gsc.sort=date&gsc.page={}'.format(page)
# url_format = 'http://www.chinatimes.com/search/result.htm?q='+area+'#gsc.tab=0&gsc.q='+area+'&gsc.page={}'.format(page)
            try:
                driver.get(url_format)
                driver.implicitly_wait(30)
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
                driver.implicitly_wait(30)
            except:
                time.sleep(5)
                continue
        else:
            try:
                res_text = driver.page_source
                driver.find_element_by_xpath("//div[@id='___gcse_0']/div/div/div/div[5]/div[2]/div[2]/div/div[2]/div[13]/div/div[{}]".format(page+1)).click()
                driver.implicitly_wait(30)
            except:
                time.sleep(5)
                continue
                
        time.sleep(3) #避免讓伺服器察覺攻擊
        script = res_text
        getlinkv2(script)
# Out:
# c:\python27\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
#將新聞連結變成DataFrame
import pandas
data1 = pandas.DataFrame(linkary)
data1
# Out:
#     area  count                                               link  page
# 0    中正區      1  http://www.chinatimes.com/realtimenews/2015103...     1
# 1    中正區      2  http://www.chinatimes.com/realtimenews/2015102...     1
# 2    中正區      3  http://www.chinatimes.com/newspapers/201510300...     1
# 3    中正區      4  http://www.chinatimes.com/realtimenews/2015102...     1
# 4    中正區      5  http://www.chinatimes.com/cn/realtimenews/2015...     1
# 5    中正區      6  http://www.chinatimes.com/realtimenews/2015102...     1
# 6    中正區      7  http://www.chinatimes.com/newspapers/201510290...     2
# 7    中正區      8  http://www.chinatimes.com/realtimenews/2015102...     2
# 8    中正區      9  http://www.chinatimes.com/cn/realtimenews/2015...     2
# 9    中正區     10  http://www.chinatimes.com/newspapers/201510280...     2
# 10   中正區     11  http://www.chinatimes.com/realtimenews/2015102...     2
# 11   中正區     12  http://www.chinatimes.com/realtimenews/2015102...     2
# 12   中正區     13  http://www.chinatimes.com/newspapers/201510280...     2
# 13   中正區     14  http://www.chinatimes.com/realtimenews/2015102...     2
# 14   中正區     15  http://www.chinatimes.com/newspapers/201510260...     3
# 15   中正區     16  http://www.chinatimes.com/newspapers/201510260...     3
# 16   中正區     17  http://www.chinatimes.com/newspapers/201510260...     3
# 17   中正區     18  http://www.chinatimes.com/realtimenews/2015102...     3
# 18   中正區     19  http://www.chinatimes.com/realtimenews/2015102...     3
# 19   中正區     20  http://www.chinatimes.com/newspapers/201510250...     3
# 20   中正區     21  http://www.chinatimes.com/newspapers/201510240...     3
as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        linkary.append(row)

# %%
import requests
from bs4 import BeautifulSoup
import pandas
import time

for get in linkary:
    headers = {
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
    }
    text = ''
    while True:
        try:
            url = get['link']
            res = requests.get(url, headers = headers)
            soup = BeautifulSoup(res.text)
            break
        except:
            time.sleep(5)
#----------------------------------------------------------------------------------------------    
    try:
        get['title'] = soup.select('.clear-fix h1')[0].text
#             print get['title']
        get['date'] = soup.select('.clear-fix time')[0]['datetime']
#             print get['time']
        get['like'] = soup.select('.clear-fix .num')[0].text
#             print get['like']
        for p_tag in soup.select('.clear-fix article p'):
            text += p_tag.text.strip()
        get['content'] = text
#             print get['content']
    except:
        print "This link has some problems!"
        print get['link'], get['area'], get['count']
# Out:
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 大同區 23
# This link has some problems!
# http://www.chinatimes.com/cn/newspapers/2601 松山區 5
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151025000458-260102 信義區 26
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 士林區 31
# This link has some problems!
# http://www.chinatimes.com/newspapers/20151016000688-260102 文山區 30

# %%
#輸出成檔案
import pandas
data2 = pandas.DataFrame(linkary)

#刪除多餘的欄位
cht_ok = data2.drop(data2.columns[[0]],axis=1)
cht_ok
# Out:
#     area                                            content count  \
# 0    中正區  27歲台荷混血的鄭姓男子，自稱求職不順，在台北流浪多年，經常睡公園或地下道，生活十分坎坷，8...     1
# 1    中正區  建置多元收益能量，炎洲(4306)、上曜(1316)近年積極部署建案投資，惟近年打房力道衝擊...     2
# 2    中正區  國內最權威、規模最盛大的企業、建築獎項「第17屆國家建築金質獎暨第12屆國家品牌玉山獎」頒獎...     3
# 3    中正區  國內最具規模，有184隊、參賽人數超過2000人的第8屆校園10人11腳競速大對決，10月3...     4
# 4    中正區  27岁台荷混血的郑姓男子，自称求职不顺，在台北流浪多年，经常睡公园或地下道，生活十分坎坷，8...     5
# 5    中正區  (12:30更新)台北地檢署接獲美國在台協會AIT檢舉，指有跨國賣淫集團，北檢發交大安警分局...     6
# 6    中正區  中埔鄉設計師江承峻小時候只能看著同學掏錢玩雜貨店刮刮卡，缺憾經驗讓他在有能力成立工作室時，立...     7
# 7    中正區  ※迪士尼年終聖誕大驚喜！《冰雪奇緣 冰紛特展》盛大開展！影史上最賣座的動畫電影：迪士尼《冰雪...     8
# 8    中正區  国内最具规模，有184队、参赛人数超过2000人的第8届校园10人11脚竞速大对决，10月3...     9
# 9    中正區  基隆貨櫃車違規偷跑中正高架橋，警方取締防不勝防！自去年5月底開始，除東、西岸碼頭尖轉運車輛於...    10
# 10   中正區  不動產市場颳寒風，10月不動產處分大賽最後一棒，國產署第5批11宗國有地設定地上權招標昨(2...    11
# 11   中正區  涉嫌於昨日持槍闖入兆豐銀行台北衡陽分行搶劫未遂的的搶匪，警方查出是住新北市三重區的林姓男子，...    12
# 12   中正區  榮民醫院將鹿滿院區焚化爐外包焚燒醫療廢棄物，深夜臭氣籠罩引爆竹崎鄉民抗議，焚化爐停運5年，鄉...    13
# 13   中正區  搶銀行未遂！位於北市中正區衡陽路91號的兆豐銀行衡陽分行，今（26）日下午2點半左右，1名搶...    14
# 4                            台荷混血儿 自称坎坷偷机车
# 5                      太陽花女王劉喬安涉跨國賣淫 5萬元交保
# 6                          省刮刮樂錢 設計師認養非洲貧童
# 7    Disney Frozen『冰雪奇緣 冰紛特展』 早鳥優惠限時搶購開跑囉！
# 8                   第8届校园10人11脚竞速对决 周六热烈开跑
# 9                           基隆中正高架橋 貨櫃車又偷跑
# 10                  《傳產》國產署設定地上權招標冷清，僅2宗脫標
# 11                           兆豐銀行搶案 搶嫌晚間投案
# 12                            焚化爐拆了 鹿滿村放鞭炮
# 13                      博愛特區兆豐銀驚傳搶案 打傷保全逃逸
# 14                           台省城隍廟遶境 陸客搶拍照
# 15                          文創中介經紀論壇 28日登場
# 16                            名家觀點－南海問題下一步
# 17                              HBL的「成功」效應
# 18                          省城隍廟遶境 2500人參與
# 19                          兩岸史話－兩岸二戰時不是敵國
# 20                          兩岸史話－兩岸二戰時不是敵國
# 21                           吳育仁推公平勞動 幸福工程
# 22                           時論－蔡英文思想錯亂的根源
# 23                            台北市605個路段飲鉛水
# 24                      黑豹旗64強中正高中被逆轉 球員痛哭
# 25                             釀酒師返鄉打造葡萄酒區
# 26                             全球最佳機場 桃機第4
# 27                            提高癌篩率 小小兵出任務
# 28                            提高癌篩率 小小兵出任務
# 29                  莫忘來時路／10月19日－桃機規畫趕不上變化
# ..                                     ...
# 482                        公有屋頂變菜園 爺奶的開心農場
# 483                        公有屋顶变菜园 爷奶的开心农场
# 484                      鉛管用戶減免水費 每月25～38元
# 485                       練台生投資北都有線 NCC今審議
# 486                           公共保母制 議員籲提配套
# 487                            臺北詩歌節 替靈魂打氣
# 488                       HBL資格賽 木柵高工獲甲級首勝
# 489                          雙園社區公共保母站 今登記
# 490                          夜夜夢冤魂 頂罪男供出真凶
# 491                         靈骨塔業務兼販毒 開毒趴被逮
# 492                      《桃園三結義》 裴艷玲跨行當演張飛
# 493                           台北市605個路段飲鉛水
# 494                          知名夜市、商圈中標：快換管
# 495                           幸福學院揭牌 祖孫同學樂
# 496                         陪祖孫過重陽 柯：拓育兒據點
# 497                    陸京劇裴豔玲大師來台演出「桃園三結義」
# 498                            台北人購屋比 六都最低
# 499                        建商減量保價 北市新屋供給腰斬
# 500                        政大野火陣線不滿校歌 校園噴漆
# 501                        基隆／台北治理經驗替基隆謀福利
# 502                        基隆／台北治理經驗替基隆謀福利
# 503                         逾60歲 可在社區打流感疫苗
# 504                                    NaN
# 505                          大台北人口紅利區 內湖居首
# 506                       《產業》百家爭鳴，太陽光電展登場
# 507                      補充保費門檻 曾銘宗：調高有益散戶
# 508                     不滿行動派出所 王世堅：要推倒質詢台
# 509                       警專生跑步訓練昏倒 送醫救回一命
# 510                        柯文哲出席臺北市文山區健行活動
# 511                  柯文哲戴季全遭控波卡案貪瀆 特偵交北檢調查
#
# [512 rows x 8 columns]

# %%
cht_ok.to_csv('cht_ok.csv',encoding='utf-8')
