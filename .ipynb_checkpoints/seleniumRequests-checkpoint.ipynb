# %%
from seleniumrequests import Firefox
from bs4 import BeautifulSoup
webdriver.implicitly_wait(10)
webdriver = Firefox()
response = webdriver.request('get','http://www.appledaily.com.tw/realtimenews/article/property/20151027/720171/applesearch/%E9%9B%99%E5%B1%A4%E5%BA%97%E9%9D%A2%E5%A4%AF%E3%80%80%E5%8C%97%E5%B8%82%E5%83%B9%E6%A0%BC%E5%B9%B4%E6%BC%B2%E8%BF%912%E6%88%90')
soup = BeautifulSoup(response.text)
print soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]> <html lang="zh-TW" class="ie6 ielt8"> <![endif]-->
# <!--[if IE 7 ]>    <html lang="zh-TW" class="ie7 ielt8"> <![endif]-->
# <!--[if IE 8 ]>    <html lang="zh-TW" class="ie8"> <![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--> <html lang="zh-TW"> <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <title>雙層店面夯　北市價格年漲近2成 | 即時新聞 | 20151027 | 蘋果日報</title>
# <meta content="雙層店面夯北市價格年漲近2成 | 即時新聞 | 20151027 | 蘋果日報" name="Title"/>
# <meta content="雙層店面好運用，價格水漲船高，房仲統計近1年雙北店面交易實價，台北市1樓店面年減0.6%、新北年減2.6%，但若連同2樓一起出售「雙層店面」，北市今年1+2樓店面單價年增近2成、新北1+2樓店面單價也" name="description"/>
# <meta content=",地產,property,蘋果日報,地產新聞,apple daily,台灣,爽報,壹週刊,壹電視,動新聞,即時新聞,影音新聞" name="keywords"/>
# <meta content="INDEX,FOLLOW" name="Robots"/>
# <meta content="100003491041452" property="fb:admins"/>
# <meta content="244889285591923" property="fb:app_id"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@TW_nextmedia" name="twitter:site"/>
# <meta content="雙層店面夯　北市價格年漲近2成 | 即時新聞 | 20151027 | 蘋果日報" name="twitter:title">
# <meta content="雙層店面好運用，價格水漲船高，房仲統計近1年雙北店面交易實價，台北市1樓店面年減0.6%、新北年減2.6%，但若連同2樓一起出售「雙層店面」" name="twitter:description">
# <meta content="https://www.facebook.com/appledaily.tw" property="article:author"/>
# <meta content="https://www.facebook.com/appledaily.tw" property="article:publisher"/>
# <meta content="蘋果日報" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="雙層店面夯　北市價格年漲近2成 | 即時新聞 | 20151027 | 蘋果日報" property="og:title"/>
# <meta content="雙層店面好運用，價格水漲船高，房仲統計近1年雙北店面交易實價，台北市1樓店面年減0.6%、新北年減2.6%，但若連同2樓一起出售「雙層店面」" property="og:description"/>
# <meta content="http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" property="og:url"/>
# <meta content="http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg" property="og:image"/>
# <meta content="http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg" name="twitter:image">
# <link href="http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg" rel="image_src" type="image/jpeg">
# <link href="http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" rel="canonical"/>
# <link href="http://twimg.edgesuite.net/appledaily/images/css/style.css" rel="stylesheet">
# <link href="http://twimg.edgesuite.net/appledaily/images/css/rtnews.css" rel="stylesheet">
# <link href="http://twimg.edgesuite.net/appledaily/images/css/modules.css" rel="stylesheet"/>
# <link href="http://twimg.edgesuite.net/appledaily/images/css/realtimenews.css" rel="stylesheet"/>
# <link href="http://twimg.edgesuite.net/appledaily/images/css/jquery.lightbox-0.5.css" rel="stylesheet"/>
# <!--Video-->
# <style type="text/css">
#     html,body{margin:0;padding:0;}
#     #mediaspace{position:absolute;top:0;left:0;display:block;width:630px;height:355px;padding:5px;}
#     #newimglayer {position:absolute;top:0;left:0;z-index:99;width:590px;height:350px;padding-left:25px;padding-top:7px;}
#     #unImage img,#newimglayer img{width:590px;height:350px;border:0;position: absolute; left:0px; top:0px;}
#     #newimglayer a.yes,#newimglayer a.no
#     {background-color: transparent;background-position:top left;background-repeat: no-repeat;position: absolute;top: 270px;display: block;width: 190px; height: 41px;z-index: 93; cursor: pointer;}
#     a.yes {background-image: url(http://twimg.edgesuite.net/appledaily/images/core/yes_bg.png);left: 120px;}
#     a.no {background-image: url(http://twimg.edgesuite.net/appledaily/images/core/no_bg.png);left:354px;}
#     #unImage{display: none;position: absolute;z-index: 1;}
#    .xy_18{position:relative;}
#    h2.shrst { left: 244px; }
#    #playerVideo {  position: relative;}
#    .sgimg {position: relative;color: #505050;font-size: 15px;line-height: 1.2em;padding-bottom: 0.75em;}
#    .rlfix img {max-width:640px;max-height:500px;margin:0px auto;display:block;}
#    .sgimg a {display: block;position: relative;overflow: hidden;border-bottom: none !important;margin: 0px auto;}
#    .sgimg .cpt {display: block;font-size: 15px;line-height: 1.3em;padding: 0.5em 0;border-bottom: 1px solid #9d9ea6;}
#    .rel_img_des p {width:600px;color: #000000;line-height: 1.5em;margin: 0px auto;font-size: 18px;}
#    .slimg span,.sgimg a span {
#    background: transparent url(http://twimg.edgesuite.net/appledaily/images/core/mggi.png) top left no-repeat;
#    position: absolute;bottom: 0;left: 0;display: block;width: 46px;height: 46px;}
#    .sglft {float: left;margin-right: 1.5em;margin-bottom: 1em;}
#    .sgrgt {float: right; margin-left: 1.5em; margin-bottom: 1em;}
#    .abdominis {padding-top:0px}
#    #rt_headpic {width:640px;overflow:hidden;background:white;margin:0px 0px 10px 0px;}
#    #rt_headpic h1 {color: #3f3f41;font-size: 1.75em;line-height: 1.3em;text-indent:5px;padding:8px 0px;}
#    #rt_headpic .new {border-top:4px solid #ECB527}
#    #rt_headpic .recommend {border-top:4px solid #3C9F5C}
#    #rt_headpic .hot {border-top:4px solid #5596D2}
#    #rt_headpic .animal {border-top:4px solid #e872af}
#    #rt_headpic .fun {border-top:4px solid #ed2556}
#    #rt_headpic .3c {border-top:4px solid #318597}
#    #rt_headpic .strange {border-top:4px solid #b213c7}
#    #rt_headpic .video {border-top:4px solid #5C48BF}
#    #rt_headpic .beauty {border-top:4px solid #ec057c}
#    #rt_headpic .sports {border-top:4px solid #A31313}
#    #rt_headpic .facebook {border-top:4px solid #0e78ff}
#    #rt_headpic .entertainment {border-top:4px solid #FF7A21}
#    #rt_headpic .fashion {border-top:4px solid #b1558b}
#    #rt_headpic .life {border-top:4px solid #E15D5A}
#    #rt_headpic .local {border-top:4px solid #577798}
#    #rt_headpic .international {border-top:4px solid #5BA5EE}
#    #rt_headpic .finance {border-top:4px solid #4B565F}
#    #rt_headpic .property {border-top:4px solid #217ad9}
#    #rt_headpic .politics {border-top:4px solid #BAA795}
#    #rt_headpic .forum {border-top:4px solid #83b400}
#    #rt_headpic .forumed {border-top:4px solid #ca4979}
#    .fb_iframe_widget_fluid {display: inline !important;}
#    .imgmid1 {position: relative;margin: 0 auto;float: left;left: 50%;}
#    .imgmid2 {position: relative;float: right;right: 50%;}
#   </style>
# <script src="http://twimg.edgesuite.net/www/js/html5.js"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/jquery-1.7.2.min.js"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/jquery.tools.dateinput.js"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/jquery.lightbox-0.5.min.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/appledaily-detectmobilebrowser.js" type="text/javascript"></script>
# <!-- OneVision, InPage -->
# <script language="JavaScript" src="http://twimg.edgesuite.net/appledaily/images/js/OneAD_Realtime_v1.js" type="text/javascript"></script>
# <!-- OneVision, InPage -->
# <script type="text/javascript">
#     // For OneAD, DON'T MODIFY the following
#     if (ONEAD){
#         ONEAD.uid = "1000001";
#         ONEAD.external_url = "http://advideoadmin.appledaily.com.tw/"; // base_url, post-slash is necessary
#         ONEAD.wrapper = 'ONEAD_player_wrapper';
#         ONEAD.category = '2-realtimenews_e';
#         ONEAD.display_type = 'inpage'; // inpage | instream
#    }
#     if (typeof window.isip_js == "undefined") {
#             (function() {
#             var src = 'http://ad-specs.guoshipartners.com/static/js/isip.v2.js';
#             var js = document.createElement('script');
#             js.async = true;
#             js.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             js.src = src;
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(js, node.nextSibling); // insert after
#             })();
#     }
#   </script>
# <script src="http://twimg.edgesuite.net/appledaily/adx1/appledailycomtw.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/adx1/flowplayer-3.2.10.min.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/adx1/flowplayer.ipad-3.2.8.min.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/adx1/flowplayer.con.js" type="text/javascript"></script>
# <script language="JavaScript" src="http://twimg.edgesuite.net/adx/gpt.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/applemobile/js/jquery.cookie.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/GeoApi.js" type="text/javascript"></script>
# <script>
#         GeoDFP['apple_daily_article_id'] = 720171;
#         googletag.cmd.push(function() {
#             var mappingHeadBanner = googletag.sizeMapping().addSize([0, 0], [ [970,90], [970,250] ]).build();
#             var mappingLREC1 = googletag.sizeMapping().addSize([0, 0], [ [300,250], [300,600] ]).build();
#             HeadBanner = gpt.createAdSlot('AppleDaily/realtimenews_property/HeadBanner', 'HeadBanner', 'leaderboard', GeoDFP).defineSizeMapping(mappingHeadBanner).setCollapseEmptyDiv(true);
#             LREC1 = gpt.createAdSlot('AppleDaily/realtimenews_property/LREC1', 'LREC', 'rectangleAD1', GeoDFP).defineSizeMapping(mappingLREC1).setCollapseEmptyDiv(true);
#             LREC2 = gpt.createAdSlot('AppleDaily/realtimenews_property/LREC2', 'LREC', 'rectangleAD2', GeoDFP);
#             W1 = gpt.createAdSlot('AppleDaily/realtimenews_property/Wallpaper1', '150x800', 'door-left', GeoDFP);
#             W2 = gpt.createAdSlot('AppleDaily/realtimenews_property/Wallpaper2', '150x800', 'door-right', GeoDFP);
#             GoldenHorse = gpt.createAdSlot('AppleDaily/realtimenews_property/GoldenHorse', '400x50', 'goldenhorse', GeoDFP);
#             textlink = gpt.createAdSlot('AppleDaily/realtimenews_property/textlink', '1x1', 'textlink', GeoDFP);
#             articlelast = gpt.createAdSlot('AppleDaily/realtimenews_property/articlelast', '336x280', 'articlelast', GeoDFP);
#             articlelast3 = gpt.createAdSlot('AppleDaily/realtimenews_property/articlelast3', '580x400', 'articlelast3', GeoDFP);
#             teadstv = gpt.createAdSlot('AppleDaily/realtimenews_property/teadstv', '1x1', 'teadstv', GeoDFP);
#             BottomBanner = gpt.createAdSlot('AppleDaily/realtimenews_property/BottomBanner', '1x1', 'div-ad-bottom', GeoDFP);
#             gpt.enableServices();
#         })
#   </script>
# <script>
#     function gplusoneCallBack(response){
#       if(response.state=='on')
#       {
#         ga('send', 'social', 'google_plus', 'share',  '雙層店面夯　北市價格年漲近2成');
#       }
#     }
#   </script>
# <script type="application/ld+json">
#     {
#       "@context": "http://schema.org",
#       "@type": "NewsArticle",
#       "headline": "雙層店面夯　北市價格年漲近2成",
#       "url": "http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/",
#       "thumbnailUrl": "http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg",
#       "dateCreated": "2015-10-27T18:54Z",
#       "articleSection": "即時_地產",
#       "creator": "即時新聞",
#       "keywords": ["地產"]
#     }
#     </script>
# <!-- Begin Kiosked -->
# <script async="async" src="//scripts.kiosked.com/loader/kiosked-loader.js?pub=11340&amp;site=11539" type="text/javascript"></script>
# <!-- End Kiosked -->
# </link></link></link></meta></meta></meta></meta></head>
# <body class="" id="instant">
# <!-- START Parse.ly Include: Standard -->
# <div id="parsely-root" style="display: none">
# <div data-parsely-site="appledaily.com.tw" id="parsely-cfg"></div>
# </div>
# <script>
#     (function(s, p, d) {
#       var h=d.location.protocol, i=p+"-"+s,
#           e=d.getElementById(i), r=d.getElementById(p+"-root"),
#           u=h==="https:"?"d1z2jf7jlzjs58.cloudfront.net"
#           :"static."+p+".com";
#       if (e) return;
#       e = d.createElement(s); e.id = i; e.async = true;
#       e.src = h+"//"+u+"/p.js"; r.appendChild(e);
#     })("script", "parsely", document);
#     </script>
# <!-- END Parse.ly Include -->
# <div class="wrapper"><div class="sqrezeer">
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "8028476" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=8028476&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <!-- 1X1 -->
# <script src="http://twimg.edgesuite.net/appledaily/images/js/1x1/nxm_tr.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/1x1/fingerprint.js" type="text/javascript"></script>
# <script src="http://twimg.edgesuite.net/applemobile/js/jquery.cookie.js" type="text/javascript"></script>
# <script>
#     function getUid() {
#         var default_udid = "0000000000";
#         var curr_ver = 1;
#         var sig = $.cookie('udid');
#         var ver = $.cookie('udid_ver');
#         if (((sig != undefined) && (sig != null) && (sig) && (sig != "")) && ((ver != undefined) && (ver != null) && (ver) && (ver != "") && (curr_ver <= ver))) {} else {
#             try {
#                 var fp = new Fingerprint();
#                 sig = fp.get() + '';
#                 if (sig.length < 10) {
#                     sig = default_udid + sig;
#                     sig = sig.substr(sig.length - 10);
#                 }
#             } catch (err) {
#                 sig = default_udid;
#             }
#         }
#             return sig;
#     }
#     var uuid;
#     //cookie 裡面沒有
#     if (typeof($.cookie('uidcookie')) === 'undefined') {
#         //產生新的
#         uuid = getUid();
#         //記到 cookie
#         $.cookie('uidcookie', uuid, {
#                                 path: '/',
#                                 domain: window.location.hostname.replace("www.", ""),
#                                 expires: 365 * 100
#                             });
#     }
#     else {
#         uuid=$.cookie('uidcookie');
#     }
#     nxmTrack.nxmAddSeg("UID="+uuid);
#     nxmTrack.nxmAddSeg("REGION=TW");
#     nxmTrack.nxmAddSeg("PROD=ADAILY");
#     nxmTrack.nxmAddSeg("SITE=www.appledaily.com.tw");
#     nxmTrack.nxmAddSeg("CH=APPLEDAILY");
#     nxmTrack.nxmAddSeg("SECTION=REAL");
#     nxmTrack.nxmAddSeg("MENU=");
#     nxmTrack.nxmAddSeg("TITLE=雙層店面夯　北市價格年漲近2成");
#     nxmTrack.nxmAddSeg("SUBSECT=property");
#     nxmTrack.nxmAddSeg("SUBSUBSECT=property");
#     nxmTrack.nxmAddSeg("MEDIA=TEXT");
#     nxmTrack.nxmAddSeg("CONTENT=ARTICLE");
#     nxmTrack.nxmAddSeg("ISSUEID=20151027");
#     nxmTrack.nxmAddSeg("CID=property");
#     nxmTrack.nxmAddSeg("NEWS=REALTIME");
#     nxmTrack.nxmAddSeg("PLATFORM=WEB");
#     nxmTrack.nxmAddSeg("EDM=MOST");
#     nxmTrack.nxmAddSeg("VERSION=");
#     nxmTrack.nxmAddSeg("DEVICE=");
#     nxmTrack.nxmAddSeg("ACTION=pageview");
#     nxmTrack.nxmAddSeg("DID=");
#     nxmTrack.nxmAddSeg("LAT=");
#     nxmTrack.nxmAddSeg("LON=");
# </script>
# <style>
#     #door {position:relative; width:970px; margin-top:45px;}
#     #door-left{position:absolute;left:-155px;}
#     #door-right{position:absolute;right:-155px;}
#     #ypv {float:right;margin:-71px 400px 0px 0px;}
#     #ypv a {color:#055b94}
#     .nypv {background: url('http://twimg.edgesuite.net/appledaily/images/core/iconset.png') 0px -41px no-repeat;display: inline-block;color: #055b94;width:14px;height:12px;}
#     #corpnav a {padding: 0 8px 0 8px;}
#     a.mc {left:580px;}
# </style>
# <header id="globehead">
# <div class="sqzer">
# <hgroup>
# <h2 class="nlogo"><a class="nextmedia overcooked" href="http://www.nextdigital.com.hk/investor/">This is a part of NextMedia</a></h2>
# <h1 class="rlogo"><a class="overcooked" href="/realtimenews">蘋果日報 | APPLE DAILY</a></h1>
# </hgroup>
# <nav id="corpnav">
# <a class="opacity first" href="http://epl.appledaily.com.tw/" target="_blank"><img alt=" 蘋果足球" src="http://twimg.edgesuite.net/appledaily/images/core/logo_menubar.gif"/></a>
# <a class="opacity " href="/" target="_blank"><img alt=" 蘋果日報" src="http://twimg.edgesuite.net/appledaily/images/core/menu_AppleDaily.png"/></a>
# <a class="opacity" href="http://www.applelive.com.tw/livechannel/" target="_blank"><img alt=" 蘋果Live" src="http://twimg.edgesuite.net/appledaily/images/core/applelive.gif"/></a>
# <a class="opacity" href="/animation/" target="_blank"><img alt=" 動新聞" src="http://twimg.edgesuite.net/appledaily/images/core/menu_AnimatedNews.png"/></a>
# <a class="opacity" href="http://sharpdaily.tw/" target="_blank"><img alt="爽報" src="http://twimg.edgesuite.net/appledaily/images/core/menu_SharpDaily.png"/></a>
# <a class="opacity" href="http://www.nextmag.com.tw/" target="_blank"><img alt="壹週刊" src="http://twimg.edgesuite.net/appledaily/images/core/menu_NextMag.png"/></a>
# <a class="opacity" href="http://www.eat-travel.com.tw/" target="_blank"><img alt="飲食男女" src="http://twimg.edgesuite.net/appledaily/images/core/menu_eatintravel.png"/></a>
# <a class="opacity" href="http://tw.tomonews.net/" target="_blank"><img alt="Tomonews" src="http://twimg.edgesuite.net/appledaily/images/core/menu_tomonews_s.png"/></a>
# <a class="opacity" href="https://www.youtube.com/user/twappledaily/" target="_blank"><img alt="youtube" src="http://twimg.edgesuite.net/appledaily/images/core/menu_youtube.png"/></a>
# <a class="opacity last" href="http://tour.eat-travel.com.tw/" target="_blank"><img alt="旅遊王" src="http://twimg.edgesuite.net/appledaily/images/core/travellogo.png"/></a>
# </nav>
# <section id="worldwide">
# <a class="tw on" href="http://www.twnextdigital.com/">台灣 </a>
# <a class="hk" href="http://www.nextdigital.com.hk/">香港 </a>
# </section>
# <section id="ypv">
# <a href="/index/applepv/" target="_blank"><span class="nypv"></span><span>昨日瀏覽量 : </span><span id="pv"></span></a>
# </section>
# <div style="clear:both"></div>
# <section id="corpgs">
# <a class="mc" href="/ethics/index.html" target="_blank">蘋果日報自律委員會</a>
# <a class="fund" href="/charity" style="background-image:url('http://twimg.edgesuite.net/appledaily/images/core/foundation_top.png');width:65px;height:14px;margin-left:720px" target="_blank"></a>
# <a class="nxlik" href="http://www.nextdigital.com.hk/investor/" target="_blank"><span class="nh overcooked">Nextmedia</span></a>
# </section>
# <section id="door">
# <div id="door-left"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('door-left');})</script></div>
# <div id="door-right"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('door-right');})</script></div>
# </section>
# </div>
# </header>
# <style>
#     .navlv2 {width: 88px;}
#     .rsearch {border-right:0px}
#     #newnav .boomed a,#newnav .boom a:hover {background-color:#EC7F27;color: #FFFFFF;}
#     #newnav .new a:hover,#newnav .newed a {background:#D50404}
# </style>
# <nav id="realnav">
# <div id="newnav">
# <ul>
# <li class="new navlv2 nav1line"><a href="/realtimenews/section/new/" title="最新">最新</a></li>
# <li class="recommend navlv2 nav1line"><a href="/realtimenews/section/recommend/" title="焦點">焦點</a></li>
# <li class="hot navlv2 nav1line"><a href="/realtimenews/section/hot/" title="熱門">熱門</a></li>
# <li class="boom navlv2 nav1line"><a href="http://www.appledaily.com.tw/complainevent" target="_blank" title="爆社">爆社</a></li>
# <li class="zoo navlv2 nav1line"><a href="/realtimenews/section/animal/" title="動物">動物</a></li>
# <li class="fun navlv2 nav1line"><a href="/realtimenews/section/fun/" title="FUN">FUN</a></li>
# <li class="ccc navlv2 nav1line"><a href="/realtimenews/section/3c/" title="3C">瘋啥</a></li>
# <li class="rsea navlv2 nav1line"><a href="/realtimenews/section/strange/" title="搜奇">搜奇</a></li>
# <li class="video navlv2 nav1line"><a href="/realtimenews/section/video/" title="影片">影片</a></li>
# <li class="hotg navlv2 nav1line"><a href="/realtimenews/section/beauty/" title="正妹">正妹</a></li>
# <li class="sport navlv2 nav1line"><a href="/realtimenews/section/sports/" title="體育">體育</a></li>
# <li class="enter navlv2"><a href="/realtimenews/section/entertainment/" title="娛樂">娛樂</a></li>
# <li class="fashion navlv2"><a href="/realtimenews/section/fashion/" title="時尚">時尚</a></li>
# <li class="life navlv2"><a href="/realtimenews/section/life/" title="生活">生活</a></li>
# <li class="soci navlv2"><a href="/realtimenews/section/local/" title="社會">社會</a></li>
# <li class="inter navlv2"><a href="/realtimenews/section/international/" title="國際">國際</a></li>
# <li class="business navlv2"><a href="/realtimenews/section/finance/" title="財經">財經</a></li>
# <li class="houseed navlv2"><a href="/realtimenews/section/property/" title="地產">地產</a></li>
# <li class="polit navlv2"><a href="/realtimenews/section/politics/" title="政治">政治</a></li>
# <li class="blog navlv2"><a href="/realtimenews/section/forum/" title="論壇">論壇</a></li>
# <li class="forum navlv2"><a href="/realtimenews/forum/" title="陣線">陣線</a></li>
# <li class="rsearch">
# <form action="http://search.appledaily.com.tw/appledaily/search" id="searchform" method="POST" name="searchform">
# <input name="searchType" type="hidden" value="text">
# <input name="searchMode" type="hidden" value="Sim">
# <input class="rsbox" id="search" name="querystrS" type="text"/>
# <input class="rsbtn" type="submit" value=""/>
# </input></input></form>
# </li>
# <div style="clear:both"></div>
# </ul>
# </div>
# </nav>
# <div class="soil">
# <div id="div-incover-ad">
# <script type="text/javascript">
#             if (typeof(ONEAD) !== "undefined"){
#                 ONEAD.cmd = ONEAD.cmd || [];
#                 ONEAD.cmd.push(function(){
#                     ONEAD_slot('div-incover-ad', 'incover');
#                     console.log('incover');
#                 });
#             }
#         </script>
# </div>
# <section class="ads" id="leaderboard"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('leaderboard');})</script></section>
# <div id="div-onead-ad">
# <script type="text/javascript">ONEAD.cmd.push(function(){ ONEAD_slot('div-onead-ad'); });</script>
# </div>
# <article class="vertebrae" id="maincontent">
# <div class="abdominis lvl">
# <div id="rt_headpic">
# <header class="property"><hgroup><h1 id="h1">雙層店面夯　北市價格年漲近2成</h1></hgroup></header>
# <figure class="lbimg sgimg rlfix">
# <div class="imgmid1">
# <div class="imgmid2">
# <a class="t1" href="http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg" title="雙層店面運用多，可做補習班、餐飲使用，價格水漲船高，今年北市價漲近2成。資料照片">
# <img src="http://twimg.edgesuite.net/images/ReNews/20151027/640_04257f8e156ca6caf28e4207e508b567.jpg"><span></span>
# </img></a>
# </div>
# </div>
# <div style="clear:both;"></div>
# <div class="rel_img_des"><p id="caption0">雙層店面運用多，可做補習班、餐飲使用，價格水漲船高，今年北市價漲近2成。資料照片</p></div>
# </figure>
# </div>
# <div class="collum">
# <section class="tlb fillup" id="toolbar">
# <h2>字級：</h2>
# <div class="fntss">
# <a class="smaller overcooked" href="javascript:doZoom(16)" id="smaller" mce_href="javascript:doZoom(16)" title="最小字型">最小字型</a>
# <a class="middle overcooked" href="javascript:doZoom(18)" id="middle" mce_href="javascript:doZoom(18)" title="預設">預設</a>
# <a class="bigger overcooked" href="javascript:doZoom(20)" id="bigger" mce_href="javascript:doZoom(20)" title="最大字型">最大字型</a>
# </div>
# </section>
# <article class="mpatc slvl clearmen">
# <div class="shrs clearmen">
# <a class="facebook overcooked" href="javascript:desc='';via='';if(document.referrer)via=document.referrer;if(typeof(_ref)!='undefined')via=_ref;if(window.getSelection)desc=window.getSelection();if(document.getSelection)desc=document.getSelection();if(document.selection)desc=document.selection.createRange().text;void(open('http://www.facebook.com/share.php?u='+encodeURIComponent('http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/')));" onclick="ga('send','social', 'facebook', 'share', '雙層店面夯　北市價格年漲近2成');" title="Facebook">分享到 Facebook</a>
# <a data-callback="gplusoneCallBack" href="https://plus.google.com/share?url=http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" onclick="javascript:window.open(this.href,'', 'menubar=no,toolbar=no,resizable=yes,scrollbars=yes,height=600,width=600');return false;"><img src="http://twimg.edgesuite.net/appledaily/images/rw100_g.png"/></a>
# <a class="plurk overcooked" href="javascript:void(window.open('http://www.plurk.com/?qualifier=shares&amp;status='.concat(encodeURIComponent('http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/')).concat(' ').concat('(').concat(encodeURIComponent(document.title)).concat(')')));" onclick="ga('send','social', 'plurk','share', '雙層店面夯　北市價格年漲近2成');" title="Plurk">分享到 Plurk</a>
# <a class="twitter overcooked" href="javascript:void(window.open('http://twitter.com/home/?status='.concat(encodeURIComponent(document.title)).concat(' ').concat(encodeURIComponent('http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/'))));" onclick="ga('send','social', 'twitter', 'share', '雙層店面夯　北市價格年漲近2成');" title="Twitter">分享到 Twitter</a>
# </div>
# <div class="gggs" style="position:absolute;">
# <time class="" datetime="2015/10/27/">2015年10月27日18:54</time>
# <div class="fb-send" data-href="http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" style="margin-top:3px;margin-left: 5px;margin-right: 5px;"></div>
# <div class="fb-like" data-href="http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" data-layout="button_count" data-send="false" data-show-faces="false" data-width="80" id="fb-like-id" style="margin-right: 6px;"></div>
# <div class="g-plusone" data-size="medium"></div>
# </div>
# <div class="articulum" style="margin-top:50px;">
# <p id="summary" style="word-wrap: break-word;">雙層店面好運用，價格水漲船高，房仲統計近1年雙北店面交易實價，台北市1樓店面年減0.6%、新北年減2.6%，但若連同2樓一起出售「雙層店面」，北市今年1+2樓店面單價年增近2成、新北1+2樓店面單價也有2.6%漲幅。 <br/> <br/>據優美地產企研室統計，今年與去年店面交易行情，發現北市1樓店面每坪114.4萬元，但1+2樓雙層出售的店面價格，從去年平均每坪116萬元，漲至今年138萬元，年漲19%；新北1樓店面每坪59.5萬元，若1+2樓雙層出售，則從去年每坪61.1萬元漲至今年62.7萬元，年漲2.6%。<br/> <br/> 優美地產企研室召集人葉立敏表示，房產價量齊跌，店面因有報酬率支撐，仍吃香；但1樓房價與租金行情置頂，漲幅空間有限，且釋出量少，今年反倒以「雙層」中、小坪數店面產品為主流，鎖定區域型承租方，能夠「穩定收租、減少空置期」為投資方向，若分層出租則可創造更高投報效益，在房價逆勢中不跌反漲。<br/> <br/>實價登錄顯示，今年成交最高單價、也最高總價的1+2樓雙層店面，為台北市中正區懷寧街24號的「八方雲集」鍋貼店，總價9500萬元，單價296.1萬元，兩層樓共32.1坪。<br/> <br/>葉立敏分析，該店面位在台北車站補習街商圈，有補習街學生人潮和上班族客群，區域客層穩定，吸引連鎖品牌的承租方進駐，也較能長久經營，投報續航力較佳，因而創下今年1+2樓店面新高行情。（于靜芳／台北報導）<br/><br/><a href="http://www.applelive.com.tw/livechannel/subject/152/" target="_blank"><font color="#0066cc">「蘋果掀房事」每周三中午12點半，午餐加好料～</font></a><br/><br/>更多房地產新聞，請參考<a href="https://www.facebook.com/appledailyhouse?fref=ts" target="_blank"><font color="#0066cc">蘋果地產王粉絲團</font></a></p>
# <div style=" clear:both"></div>
# <div id="teadstv"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('teadstv');})</script><br/></div>
# <div id="goldenhorse"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('goldenhorse');})</script><br/></div>
# <div id="textlink"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('textlink');})</script><br/></div>
# <a href="/realtimenews/forum/" style="font-size:20px; color:#7d2b77; font-weight:bold;" target="_blank">【蘋論陣線】：最新評論及獨立媒體每日總覽</a><br><br>
# <a _moz_dirty="" href="mailto:onlineopinions@appledaily.com.tw?subject=%A6%B3%B8%DC%ADn%BB%A1%A7%EB%BDZ%A1u%A7Y%AE%C9%BD%D7%BE%C2%A1v" style="font-size:20px; color:#12A230; font-weight:bold;">有話要說 投稿「即時論壇」<br><br> onlineopinions@appledaily.com.tw</br></br></a>
# </br></br></div>
# </article>
# <section id="articlelast" style="text-align:center"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('articlelast');})</script></section>
# <div class="artiswer fillup slvl">
# <a class="swnx" href="/realtimenews/article/property/20151030/722112/這款豪宅工地好乾淨　做工完可以洗香香/">這款豪宅工地好乾淨　做工完可以...</a> </div>
# </div>
# <aside class="rtlstisd" id="realtimelist"></aside>
# <hr class="clearman"/>
# </div>
# <!--十月圍城-->
# <script src="http://twimg.edgesuite.net/property/js/jquery.carouFredSel-6.2.1.js" type="text/javascript"></script>
# <style>
# #october {width:650px;height:200px;overflow:hidden;}
# #october .slidebox {width:650px;height:200px;}
# #october .slidebox .pics {float:left;width:650px;height:183px;overflow:hidden;margin:10px 2px 10px 2px;}
# #october .slidebox .pics img {max-width:650px;height:auto;}
# </style>
# <div style="width:100%;margin-top:-10px;"></div>
# <div id="october">
# <div class="slidebox">
# <div class="pics">
# <a href="http://goo.gl/hlOhaZ" target="_blank"><img src="http://twimg.edgesuite.net/appledaily/data/oct/a57ce4eeb3bed433f097723ad69ef1e8.jpg"/></a>
# </div>
# </div>
# <div class="slidebox">
# <div class="pics">
# <a href="http://goo.gl/uilrxX" target="_blank"><img src="http://twimg.edgesuite.net/appledaily/data/oct/b9ca826ac7f00dfe67297895ebbc44d2.jpg"/></a>
# </div>
# </div>
# <div class="slidebox">
# <div class="pics">
# <a href="http://goo.gl/Ku7VUG" target="_blank"><img src="http://twimg.edgesuite.net/appledaily/data/oct/ae183b2f0445528ab73c6725cf4a5387.jpg"/></a>
# </div>
# </div>
# <div class="slidebox">
# <div class="pics">
# <a href="http://goo.gl/YUDxVn" target="_blank"><img src="http://twimg.edgesuite.net/appledaily/data/oct/f6cd6721a8ee7ae6f47119aab331a4c9.jpg"/></a>
# </div>
# </div>
# <div class="slidebox">
# <div class="pics">
# <a href="http://goo.gl/8mI5a3" target="_blank"><img src="http://twimg.edgesuite.net/appledaily/data/oct/d25ea876adabdc74110cb761ead6e4a8.jpg"/></a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# $(document).ready(function() {
#     $('#october').carouFredSel({
#         items: 1,
#         direction: "up",
#                 infinite: true,
#                 circular: true,
#         scroll: {
#                     items: 1,
#                     duration: 1250,
#                     timeoutDuration: 2500,
#                     easing: 'swing',
#                     pauseOnHover: 'immediate'
#                 },
#     });
# });
# </script>
# <!--十月圍城-->
# <div class="clearmen">
# <div style="text-align:center"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('articlelast3');})</script></div>
# <div id="fb-root"></div><div class="fb-comments" data-href="http://www.appledaily.com.tw/realtimenews/article/new/20151027/720171/" data-num-posts="3" data-width="640"></div> <section class="jac slvl">
# </section>
# <section class="asob lvl">
# <header><h1>推薦閱讀 </h1></header>
# <article>
# <ul>
# <li><a class="" href="/realtimenews/article/property/20151029/721516/房仲抽抽樂　最大獎服務費全免/">房仲抽抽樂　最大獎服務費全免</a></li><li><a class="" href="/realtimenews/article/property/20151029/721546/海外買房熱　美國最被看好/">海外買房熱　美國最被看好</a></li><li><a class="" href="/realtimenews/article/property/20151030/722112/這款豪宅工地好乾淨　做工完可以洗香香/">這款豪宅工地好乾淨　做工完可以洗香香</a></li><li><a class="" href="/realtimenews/article/property/20151030/722148/長鴻再退票　累計已達2.56億元/">長鴻再退票　累計已達2.56億元</a></li><li><a class="" href="/realtimenews/article/property/20151028/720850/別再撐！　高雄建案殺很大來客多1倍/">別再撐！　高雄建案殺很大來客多1倍</a></li> </ul>
# </article>
# </section>
# </div>
# </article>
# <aside class="manu lvl" id="sitesidecontent">
# <div class="ads rtb rtf" id="rectangleAD1"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('rectangleAD1');})</script></div>
# <div class="ads rtb" id="rectangleAD2"><script type="text/javascript">googletag.cmd.push(function() {googletag.display('rectangleAD2');})</script></div>
# <section class="shsb slvl clearmen shsbinternational" id="section-hot-sidebox"><header><h1>國際最 Hot</h1><span><a href="/appledaily/hotdaily/international" target="_blank">看更多</a></span></header><article><ul><li><h2><a href="/appledaily/article/international/20151030/36871675/hotdailyart_right">AV男優清水健 教你怎麼延...</a></h2><span>32022</span></li><li><h2><a href="/appledaily/article/international/20151030/36871515/hotdailyart_right">美擬派航母 中嗆：兵來將擋</a></h2><span>31022</span></li><li><h2><a href="/appledaily/article/international/20151030/36871746/hotdailyart_right">直擊男女在辦公室野砲　民眾...</a></h2><span>21820</span></li><li><h2><a href="/appledaily/article/international/20151030/36871761/hotdailyart_right">韓國人受不了強國觀光客啦 ...</a></h2><span>14050</span></li><li><h2><a href="/appledaily/article/international/20151030/36871749/hotdailyart_right">南蘇丹內戰設性奴營 逼吃人...</a></h2><span>9558</span></li></ul></article></section>
# <!--crowdynews ad-->
# <div data-crowdynews-widget="AppleDaily/taipei-vertical" style="width: 300px; height: 400px;"><script async="true" src="//widget.crowdynews.com/js/widget.js"></script></div>
# <section class="fbbx slvl clearmen" id="facebookbox">
# <header>
# <h1>Facebook </h1>
# <a class="on" id="fblikebtn">蘋果粉絲團</a>
# </header>
# <article>
# <div id="fb-root"></div>
# <script language="javascript">
#             (function(d, s, id) {
#               var js, fjs = d.getElementsByTagName(s)[0];
#               if (d.getElementById(id)) return;
#               js = d.createElement(s); js.id = id;
#               js.src = "//connect.facebook.net/zh_TW/all.js#xfbml=1";
#               fjs.parentNode.insertBefore(js, fjs);
#             }(document, 'script', 'facebook-jssdk'));
#         </script>
# <div id="changeFBlike">
# <div class="fb-like-box" data-header="false" data-height="370" data-href="http://www.facebook.com/appledaily.tw" data-show-border="true" data-show-faces="false" data-stream="true" data-width="300"></div>
# </div>
# </article>
# </section> </aside>
# </div>
# <script type="text/javascript">//更改字級大小
#         function doZoom(size) {
#             size=size*1;
#             $('#smaller').removeClass();
#             $('#middle').removeClass();
#             $('#bigger').removeClass();
#             $('#smaller').addClass('smaller overcooked');
#             $('#middle').addClass('middle overcooked');
#             $('#bigger').addClass('bigger overcooked');
#             switch(size){
#                 case 16:
#                     $('#smaller').addClass('smon');
#                     break;
#                 case 18:
#                     $('#middle').addClass('mion');
#                     break;
#                 case 20:
#                     $('#bigger').addClass('bion');
#                     break;
#             }
#             document.cookie="FRONTSIZE="+size+"; path=/";
#             document.getElementById('h1').style.fontSize=(size+8)+'px';
#             document.getElementById('summary').style.fontSize=size+'px';
#             document.getElementById("caption0").style.fontSize=size+"px";        }
#
#         function changePage(SeoSec,IssueID,art_id,page){
#             $.ajax({
#                 url: '/realtimenews/ajaxarticle/'+SeoSec+'/'+IssueID+'/'+art_id+'/'+page+'/201510301614',
#                 dataType: 'html',
#                 type:"GET",
#                 error: function(xhr) {
#                 },
#                 success: function(response) {
#                     $('#realtimelist').html(response);
#                 }
#             });
#           }
#
#           function getCookieData(name) {
#              var patrn = new RegExp( "^" + name + "=(.*?);" ),
#                    patr2 = new RegExp( " " + name + "=(.*?);" );
#              if ( match = (document.cookie.match(patrn) || document.cookie.match(patr2)) )
#                    return match[1];
#              return false;
#           }
#
#           $(document).ready(function() {
#               fontsize = getCookieData('FRONTSIZE');
#               if(fontsize) {
#                     doZoom(fontsize);
#                 }
#                 else {
#                     doZoom(18);
#                 }
#                 changePage('property',20151027,720171,1);
#                 $('.lbimg a').lightBox();
#                 $.ajax({
#                             url: 'http://weblogging.appledaily.com.tw/api/SetClick/r/v/720171/119/0/20151027/realtimenews/'+Math.random(),
#                             dataType: 'jsonp',
#                             success: function(data) {}
#                         });
#                           });
#
#         dataLayer = [{
#         'pageLevel' : 'Article', //CD05 Homepage / Listing / Videowall / Article
#         'videoArticle': 'non-video', //CD06 or non-video
#         'publishDay': 'Thursday',  //CD09 出版日
#         'columnist' : '', //CD10 專欄作者
#         'column' : ''  //CD11 專欄名稱
#         }];
#     </script>
# <div><script type="text/javascript">googletag.cmd.push(function() {googletag.display('div-ad-bottom');})</script></div>
# <link href="http://twimg.edgesuite.net/appledaily/images/css/dateinput_skin.css" rel="stylesheet"/>
# <div class="abkct clearmen"><a class="abktp" onclick="javascript:window.scroll(0,0)">回到最上面</a></div>
# <section class="fexbr" id="extras">
# <div class="sqzer fillup">
# <a class="dyw" href="/index/dailyquote/" title="每日一句"><span data-tooltip="每天一句好話"></span>每日一句</a>
# <a class="lnr" href="/index/lottery" title="樂透發票"><span data-tooltip="看看你手氣"></span>樂透發票</a>
# <a class="oneg" href="#" onclick="JavaScript:window.open('/index/englishlearning/','','width=650,height=495')" title="線上美語"><span data-tooltip="學習英文"></span>線上美語</a>
# <a class="wkw" href="/index/weather" title="天氣"><span data-tooltip="今天一周天氣預報"></span>天氣</a>
# <a class="rpter" href="/index/complain" title="爆料投訴"><span data-tooltip="爆料給蘋果"></span>爆料投訴</a>
# <a class="itul" href="/index/prize" title="中獎名單"><span data-tooltip="蘋果送大獎！">中獎名單</span></a>
# <a class="pguss" href="/index/ticket" title="贈獎活動"><span data-tooltip="贈獎活動"></span>贈獎活動</a>
# <a class="wmvs" href="/index/mobileguide" title="行動版"><span data-tooltip="行動版">行動版</span></a>
# </div>
# </section>
# <footer id="corpfoot">
# <div class="sqzer">
# <figure><a href="http://www.nextdigital.com.hk/investor/"><img src="http://twimg.edgesuite.net/images/NextDigital/logo_NextMedia_m.png"/></a></figure>
# <section class="clearmen" id="corpcompanies">
# <a class="first" href="/" target="_blank"><img alt="蘋果日報 AppleDaily" src="http://twimg.edgesuite.net/appledaily/images/core/ft_AppleDaily.png"/></a>
# <a href="http://epl.appledaily.com.tw/" target="_blank"><img alt="蘋果足球" src="http://twimg.edgesuite.net/appledaily/images/core/logo_menubar.gif"/></a>
# <a href="/animation" target="_blank"><img alt="動新聞" src="http://twimg.edgesuite.net/appledaily/images/core/ft_AnimatedNews.png"/></a>
# <a href="http://www.applelive.com.tw/livechannel/" target="_blank"><img alt="蘋果Live" src="http://twimg.edgesuite.net/appledaily/images/core/applelive.gif"/></a>
# <a href="http://sharpdaily.tw/" target="_blank"><img alt="爽報" src="http://twimg.edgesuite.net/appledaily/images/core/ft_SharpDaily.png"/></a>
# <a href="http://www.nextmag.com.tw/" target="_blank"><img alt="壹周刊" src="http://twimg.edgesuite.net/appledaily/images/core/ft_NextMag.png"/></a>
# <a href="http://www.eat-travel.com.tw/" target="_blank"><img alt="飲食男女" src="http://twimg.edgesuite.net/appledaily/images/core/ft_eatintravel.png"/></a>
# <a href="http://fashion.appledaily.com.tw/" target="_blank"><img alt="蘋果時尚" src="http://twimg.edgesuite.net/appledaily/images/core/applefashion_website_head_39x30.png"/></a>
# <a href="http://tw.tomonews.net/" target="_blank"><img alt="Tomonews" src="http://twimg.edgesuite.net/appledaily/images/core/menu_tomonews_s.png"/></a>
# <a class="last" href="https://www.youtube.com/user/twappledaily/" target="_blank"><img alt="Youtube" src="http://twimg.edgesuite.net/appledaily/images/core/ft_youtube.png"/></a>
# <a class="last" href=" http://tour.eat-travel.com.tw/" target="_blank"><img alt="旅遊王" src="http://twimg.edgesuite.net/appledaily/images/core/travellogo.png"/></a>
# </section>
# <section class="fillip" id="corpinfo">
# <a href="/rss/" style="color:red">RSS</a>
# <a href="/index/aboutus/">了解蘋果日報</a>
# <a href="/index/contactus/">聯絡我們</a>
# <a href="/adguide" target="_blank">廣告刊登</a>
# <a href="/index/faq/">常見問題</a>
# <a href="/index/sitemap/">網站導覽</a>
# <a href="/index/termofuse/">使用條款</a>
# <a href="/index/authorization/">授權申請程序</a>
# <a href="/index/privacy/">隱私權說明</a>
# <a href="/index/disclaimer/">免責與分級</a>
# <a href="/index/community/">蘋果社群</a>
# <a href="http://www.facebook.com/nextmediastudent/" target="_blank">校園培果計畫</a>
# <a href="http://www.1111.com.tw/job-bank/company-description.asp?nNo=2785257" target="_blank">蘋果徵才</a>
# <a class="last" href="/index/subscribe">訂閱蘋果</a>
# </section>
# <p id="copyright">© 2015 www.appledaily.com.tw Limited. All rights reserved. 台灣蘋果日報 版權所有 不得轉載</p>
# </div>
# </footer>
# <link href="http://twimg.edgesuite.net/appledaily/images/css/appledaily.backtotop.css" rel="stylesheet"/>
# <script src="http://twimg.edgesuite.net/appledaily/images/js/jquery.appledaily.backtotop.js"></script>
# <div class="back-to-top-side"><a class="back-to-top-btn overcooked" onclick="javascript:window.scroll(0,0)">回到最上面</a></div><!-- .back-to-top-side -->
# <script type="text/javascript">
#     $(document).ready(function() {
#        var opacity = 0.5,
#             toOpacity = 1,
#             duration = 250;
#         $('.opacity').css('opacity', opacity).hover(function() {
#             $(this).fadeTo(duration, toOpacity);
#         }, function() {
#             $(this).fadeTo(duration, opacity);
#         });
#
#        $.ajax({
#                    url: '/index/getpv/',
#                    success: function(response){
#                        $('#pv').html(response);
#                    }
#                });
#        $(window).scroll(function() {
#          if($(this).scrollTop()>130&&($(this).scrollTop()-(-800)<$(document).height()-350)){
#              $('#door').css('position','fixed').css('top','-45px');
#          }else{
#              $('#door').css('position','relative').css('top','0px');
#          }
#        });
#      });
# </script>
# <!-- Google Analytics -->
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#       (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-2067247-40', 'auto', {'sampleRate':1});
#   ga('require', 'linkid', 'linkid.js');
#   ga('require', 'displayfeatures');
#
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-P5MXMC" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script>
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-P5MXMC');
# </script>
# <div id="nxm_iframeDiv" style="display:none"></div>
# <!--page idle-->
# <link href="http://twimg.edgesuite.net/appledaily/images/adidle/css/fancybox.css" rel="stylesheet" type="text/css">
# <script src="http://twimg.edgesuite.net/appledaily/images/adidle/js/plugin.js"></script>
# <script src="http://twimg.edgesuite.net/appledaily/images/adidle/js/adidle.js"></script>
# <script language="JavaScript">
#     document.write('<a class="pageidle" data-fancybox-type="iframe" href="/index/adidle#'+Math.random()+'"></a>');
# </script>
# <!--page idle-->
# </link></div>
# </div>
# <script src="https://apis.google.com/js/plusone.js" type="text/javascript"></script>
#
#     // Yahoo AD
#     <script type="text/javascript">
#         var sectionCode = sectionCode || [];
#         sectionCode.push("ee9bb755-a779-48b6-b820-0b20e2277e7e", "4c6898d0-0bb2-441c-84b7-42d2ef949c15");
#         (function(){
#           var script = document.createElement("script");
#           script.async = true;
#           script.src = "https://s.yimg.com/av/gemini/ga/gemini.js";
#           document.body.appendChild(script);
#         })();
#     </script>
# </body>
# </html>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-294709104fbe> in <module>()
# ----> 1 print soup.select('.pluginCountButton .pluginCountNum .pluginCountTextDisconnected').text
#
# AttributeError: 'list' object has no attribute 'text'
