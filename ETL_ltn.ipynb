# %%
def getinfo(soup):
    abnormal = 'http://talk.ltn.com.tw/article/'
    normal = 'http://news.ltn.com.tw'
    link_ary = []
    for news_list in soup.select('#newslistul li')[0:]:
        a_tag = news_list.select('a')[0]['href']
        link_ary.append(a_tag)
        for link_ele in link_ary:
            if "opinion" in link_ele:
                sp_link =  link_ele.split('/')
                link1 = abnormal + '/'.join(sp_link[3:5])
                webdriver = Firefox()
                response = webdriver.request('GET', link1)
                BeautifulSoup(response.text)
                titles = soup2.select('.conbox h2')[0].text
                times = soup2.select('.writer span')[1].text
                for p in soup2.select('.conbox p'):
                    text = p.text.strip()
 
            else:
                link1 = normal + link_ele
                res2 = requests.get(link1, headers)
                soup2 = BeautifulSoup(res2.text)
                res2.close()
                titles = soup2.select('.content h1')[0].text
                times = soup2.select('#newstext span')[0].text
                for p in soup2.select('#newstext p'):
                    text = p.text
                
            pan_ary.append({
                "area":area,
                "title":titles,
                "link":link1,
                "time":times,
                "content":text
            })

# %%
import requests
import time
import pandas
import datetime
from bs4 import BeautifulSoup
from seleniumrequests import Firefox
from selenium import webdriver

driver = webdriver.Firefox()
driver.implicitly_wait(30)

dt = datetime.datetime.now()
yyy = dt.year
mmm = dt.month
ddd = dt.day
mm = int(mmm)-2
dd = int(ddd)-3

year = str(yyy)
smonth = str(mm)
sday = str(dd)
emonth = str(mmm)
eday = str(ddd)

ary = ["中正區"]
pan_ary = []

for area in ary:
    for page in range(1,2):
        page_format = "http://news.ltn.com.tw/search?page={}&keyword="+area+"&conditions=and&SYear="+year+"&SMonth="+smonth+"&SDay="+sday+"&EYear="+year+"&EMonth="+emonth+"&EDay="+eday+area
        page_url1 = page_format.format(page)
        driver.get(page_url1)
        res_text = driver.page_source
        soup = BeautifulSoup(res_text)
        
        headers = {
            'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Encoding':'gzip, deflate, sdch',
            'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
            'Connection':'keep-alive',
            'Host':'news.ltn.com.tw',
            'Referer':page_url1,
            'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36'
            }
        
        getinfo(soup)

driver.close()
df = pandas.DataFrame(pan_ary)
df.index.name = 'id'                                                     #設置primary key
df.to_csv('e:\\df2.csv',encoding= 'utf-8')                                #將資料寫成CSV檔
df
# Out:
#     area                                            content  \
# id
# 0    中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 1    中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 2    中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 3    中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 4    中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 5    中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 6    中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 7    中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 8    中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 9    中正區  根據房仲調查自家房價成交資訊，北市12個行政區中今年第三季房價相較去年第2季高點，計有9個行...
# 10   中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 11   中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 12   中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 13   中正區  根據房仲調查自家房價成交資訊，北市12個行政區中今年第三季房價相較去年第2季高點，計有9個行...
# 14   中正區  北市府社會局提醒，長者務必隨身攜帶身分證明文件（身分證、健保卡、敬老悠遊卡等），上述場館才得...
# 15   中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 16   中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 17   中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 18   中正區  根據房仲調查自家房價成交資訊，北市12個行政區中今年第三季房價相較去年第2季高點，計有9個行...
# 19   中正區  北市府社會局提醒，長者務必隨身攜帶身分證明文件（身分證、健保卡、敬老悠遊卡等），上述場館才得...
# （資料照，記者王英傑攝）
# 21   中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 22   中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 23   中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 24   中正區  根據房仲調查自家房價成交資訊，北市12個行政區中今年第三季房價相較去年第2季高點，計有9個行...
# 25   中正區  北市府社會局提醒，長者務必隨身攜帶身分證明文件（身分證、健保卡、敬老悠遊卡等），上述場館才得...
# （資料照，記者王英傑攝）
# 27   中正區                       童仲彥臉書全文。（圖擷取自台灣阿童─童仲彥臉書粉絲專頁）
# 28   中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 29   中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# ..   ...                                                ...
# 90   中正區                     樣品屋規劃C戶35坪，可隔3房，室內樓高3.2米，採光良好。
# 91   中正區  台北市1名楊姓女子，畢業後到科技公司上班，未料經常被老闆盧男刁難及拖欠薪資，楊父得知後大為光...
# 92   中正區  房仲業者統計北市第三季房價表現，12個行政區不但已見不到每坪百萬元的單價，甚至跌破90萬元大...
# 93   中正區              台大醫院兒童醫院B1視聽講堂舉辦胰臟腫瘤病友講座。（資料照，記者蘇孟娟攝）
# 94   中正區  根據房仲調查自家房價成交資訊，北市12個行政區中今年第三季房價相較去年第2季高點，計有9個行...
# 95   中正區  北市府社會局提醒，長者務必隨身攜帶身分證明文件（身分證、健保卡、敬老悠遊卡等），上述場館才得...
# （資料照，記者王英傑攝）
# 97   中正區                       童仲彥臉書全文。（圖擷取自台灣阿童─童仲彥臉書粉絲專頁）
# 98   中正區  北水處目前未公布哪些住戶受影響，副處長陳曼莉坦言，根據台北都市發展過程來看中正、萬華、文山確...
# 99   中正區                 北市中正區為汰換鉛水管圖，粉紅點為鉛水管（北市議員謝維洲辦公室提供）
# 100  中正區    梁文傑昨說，黨有徵詢他的意見，他反映黨若徵召他，潘建志仍會選到底，若黨可以接受，他就同意參選。
# 101  中正區  《蘋果日報》報導，北市警局婦幼隊表示，「易發生婦幼犯罪地點」中的犯罪項目包括強盜、搶奪、性侵...
# 102  中正區                 在西區門戶計畫啟動後，台北車站後站商圈將有不同面貌。(攝影／黃柏榮)
# 103  中正區                     樣品屋規劃C戶35坪，可隔3房，室內樓高3.2米，採光良好。
#
「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 1     「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 2          北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 3     「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 4          北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 5                《健康充電站》胰臟腫瘤病友講座
# 6     「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 7          北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 8                《健康充電站》胰臟腫瘤病友講座
# 9            蛋黃區房價領跌  大安信義跌破每坪百萬
# 10    「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 11         北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 12               《健康充電站》胰臟腫瘤病友講座
# 13           蛋黃區房價領跌  大安信義跌破每坪百萬
# 14             重陽節好康 長者可免費搭捷運遊台北
# 15    「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 16         北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 17               《健康充電站》胰臟腫瘤病友講座
# 18           蛋黃區房價領跌  大安信義跌破每坪百萬
# 19             重陽節好康 長者可免費搭捷運遊台北
# 20            北市3萬戶喝鉛水 全數換管要等10年
# 21    「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 22         北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 23               《健康充電站》胰臟腫瘤病友講座
# 24           蛋黃區房價領跌  大安信義跌破每坪百萬
# 25             重陽節好康 長者可免費搭捷運遊台北
# 26            北市3萬戶喝鉛水 全數換管要等10年
# 27      中正萬華鉛管密度高 童仲彥籲北水處「做點正經的」
# 28    「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 29         北市蛋黃區房價走跌 大安信義每坪掉10萬元
# ..                           ...
# 90                  萬大ONE 近萬大線站點
# 91    「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 92         北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 93               《健康充電站》胰臟腫瘤病友講座
# 94           蛋黃區房價領跌  大安信義跌破每坪百萬
# 95             重陽節好康 長者可免費搭捷運遊台北
# 96            北市3萬戶喝鉛水 全數換管要等10年
# 97      中正萬華鉛管密度高 童仲彥籲北水處「做點正經的」
# 98         鉛管供水 北水處︰多集中中正、萬華、文山等
# 99            鉛管水遍全台 連管水的經濟部都在喝！
# 100  〈台北都會〉民進黨禮讓、徵召立委選舉布局混亂 基層失望
# 101            柯P將公布性侵熱點 這些地方要小心
# 102           台北市東西區大PK 門戶計劃改造市容
# 103                 萬大ONE 近萬大線站點
# 104       〈台北都會〉嘉禾新村難全保 柯：不會那麼快拆
# 105   「誰敢欺負我女兒！」地表最強老爸揍老闆判賠3000元
# 106        北市蛋黃區房價走跌 大安信義每坪掉10萬元
# 107              《健康充電站》胰臟腫瘤病友講座
# 108          蛋黃區房價領跌  大安信義跌破每坪百萬
# 109            重陽節好康 長者可免費搭捷運遊台北
# 110           北市3萬戶喝鉛水 全數換管要等10年
# 111     中正萬華鉛管密度高 童仲彥籲北水處「做點正經的」
# 112        鉛管供水 北水處︰多集中中正、萬華、文山等
# 113           鉛管水遍全台 連管水的經濟部都在喝！
# 114  〈台北都會〉民進黨禮讓、徵召立委選舉布局混亂 基層失望
# 115            柯P將公布性侵熱點 這些地方要小心
# 116           台北市東西區大PK 門戶計劃改造市容
# 117                 萬大ONE 近萬大線站點
# 118       〈台北都會〉嘉禾新村難全保 柯：不會那麼快拆
# 119               《健康充電站》高血壓衛教講座
#
# [120 rows x 5 columns]

# %%
#讀入CSV檔
import csv
#column 欄位取出 用來建立資料表格的參考欄位
with open('e:\\df.csv', 'rb') as csvfile:
    name = csv.reader(csvfile) 
    print  name.next()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-257-5dd7603e5ade> in <module>()
#       4 with open('e:\\df.csv', 'rb') as csvfile:
#       5     name = csv.reader(csvfile)
# ----> 6     print  name.next()
#       7
#
# StopIteration:

# %%
# headers = {
#             'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
#             'Accept-Encoding':'gzip, deflate, sdch',
#             'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4',
#             'Connection':'keep-alive',
#             'Host':'news.ltn.com.tw',
#             'Referer':page_url1,
#             'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36'
#             }
# res2 = requests.get('http://talk.ltn.com.tw/article/breakingnews/1474224', headers=headers)
# soup2 = BeautifulSoup(res2.content)

# print soup2

from seleniumrequests import Firefox

# Simple usage with built-in WebDrivers:
webdriver = Firefox()
response = webdriver.request('GET', 'http://talk.ltn.com.tw/article/breakingnews/1474224')
soup2 = BeautifulSoup(response.text)

# print soup2.select('.content h1')[0].text
# print soup2.select('#newstext span')[0].text
# for p in soup2.select('#newstext p'):
#     text = p.text
#     print text

# %%
# print soup2.select('.conbox h2')[0].text
# print soup2.select('.writer span')[1].text
for p in soup2.select('.conbox p'):
    print p.text.strip()
# Out:
# 【立委候選人系列人物誌】
# 苗博雅｜台北｜文山、南中正立委擬參選人
# 從調解「411路過中正一」衝突的控場姐，到迎戰電視名嘴的廢死代表——28歲的苗博雅淡定直率的風格令人印象深刻，她也將用這種態度挑戰最深藍的台北文山、南中正區立委席次。
#
# 【請簡單自我介紹】
# 「您好，我是社民黨苗博雅，我要參加2016年立委選舉！」
# 「台灣目前面對的財政、經濟、社會問題，將在未來幾年急速惡化。為了守護我們這一代和下一代的生活，我們不能再等。台灣人不能再忍受無止盡的剝削和分贓，台灣沒時間等我們變老。請您加入我們，一起改變未來。」
#
# 【能說說妳的家庭背景嗎】
# 「小時候我被告知的，不是我是臺灣人、台北人，而是廣東人。像學校資料卡上，都是寫廣東人。」
# 「我想國族意識會基於接觸的資訊決定，加上我自己算是一個在教育體制得利的人，很會考試、念教科書，教科書又是一種最容易培養人意識形態的東西，在我青少年時期的國族意識形態和現在很不一樣。」
# 「...我很難代表父親去解釋他為什麼過去會投給國民黨，人的價值判斷是很複雜的，他是外省人的第二代，在高雄的眷村出生，這或許讓他的意識形態跟國民黨比較接近，但我想人都有改變的可能，像是我這次的參選就改變了他，會把票投給我及社民黨。」
# 「我爸支持我，我不覺得單是因為親情，而是因為知道我是一個怎麼樣的人，信任我的選擇。他理解我參與政治不是為了自己個人的名利。」
# 「我們的文宣他也都會看，我爸本來是不太會用電腦的人，但為了關注我的發言、活動，開始學著用電腦。而且他在中國這樣一個資訊封閉的地方，不但要學會用網路，還要學會翻牆。」
#
# 【為什麼會唸法律？】
# 「高中的時候很天真，覺得法律可以主持正義。比較單純的人都會對法律有一種像是日劇HERO的想像。大學時修了李茂生老師的課，開始接觸到刑罰學、犯罪學，才了解社會最黑暗底層的一面，看到這些沒有被陽光照到的人，發現社會比我原先以為的複雜很多。」
# 「學法律的人和其它專長比起來沒有甚麼特別，但會看到很多社會上最瘋狂的人所做出來最瘋狂、你無法想像的事。法院每天看到的都是你覺得正常人根本不會做的事，這些事在生活中無法解決，只好跑到法院，有心的人可以從中看出社會上需要被注意的角落。」
# 「法律這套規則是誰訂的？是一些有權力加入制定行列的人。民主時代讓我們以為大家都可以加入，事實上不是。我對一個立委的影響力和一個上市公司老闆對他的影響，會一樣嗎？」
# 「我一直認為任何事物一定都有正反兩面及受害者，法律的受害者是誰？常常是那些沒有權力加入規則制定過程的人。」
# 「當有解釋、使用法律的權力時，必須意識到手上拿的不是正義的寶劍，要小心過度傷害到沒有那麼多權力的人。如果能意識到這件事，為一些已經沒辦法喘息的人多留一些空間，我覺得這是很重要的。」
# 「正義魔人最可怕，正義魔人沒有空間去想一下『我這樣做到底對不對』。缺少反思空間的話，做錯事的可能性會變得很大。」
#
# 【覺得政治是什麼？】
# 「政治的本質，說到底就是一個決定資源怎麼分配；資源要拿去解決誰的哪些問題的過程。」
# 「現在台灣面臨的問題就是資源的分配極度不均，有權力的分配到更多的權力，有資源的人分配到更多資源，這件事情是不對的。」
# 「我不認為我是決定投入選舉才開始從政的，我覺得之前做的倡議工作也是政治的一環，參選只是從政其中一種形式，但現在決定要選了，我就會竭盡所能去接觸每一個選民。」
# 「很多人都覺得我因為反對死刑的立場會到處被嗆，其實沒有啦。我的經驗是，社會上大部分的人都是可以對話的，跟媒體呈現的其實很不一樣。做社會運動時你會聚焦在議題倡議，做選舉你則會不計一切去接觸所有的人。」
#
# 【同性戀的成長經驗與對性別議題的想法？】
# 「我自己成長的過程沒有所謂『發現自己是同志』的問題，從小到大的情況通常是『被發現是女生』。」
# 「開始跑選舉之後也是，拜票的時候曾被選民說我長得很帥，結果他看到面紙後面寫北一女，才知道原來我是女生（燦笑）。」
# 「過去在北一女、台大、新創公司、廢死聯盟⋯都是對同志很友善的場域，參選之後跨出同溫層，要面對更多不同的意見。因為身分的轉變，遇到不同的想法，我傾向不在當下爭執，公開辯論很容易，但改變一個人不是透過辯論就可以達成的。」
# 「參選之後，不像以前在街頭那麼有對抗性。因為我覺得自己要承擔多一點，對很多人來說，我是他第一個面對面的同性戀候選人，甚至是同性戀，透過接觸，他能夠了解原先認知以外的資訊。這個認知，就已經是改變的第一步了。」
# 「性別平等要真正落實的關鍵在教育與文化，在於我們的教育有沒有教導學生尊重差異。若我們有一天不再認為男生留長頭髮、穿裙子很奇怪，很多跨性別者遇到的困境就可以減少。」
# 「法律也可以引領社會的改變，婚姻平權只是性別議題的其中一項，性別是遍佈在所有層面的。」
# （畫面截自：https://youtu.be/aG_La9pWLuE）
# 【當時怎麼會在「411路過中正一」的衝突現場？】
# 「那天下午看到有人在號召要包圍中正一，覺得很好奇，也發現沒有明顯的號召者，想說如果出了甚麼狀況沒人能負責，決定下班去現場看看有沒有甚麼能協助的。」
# 「自己過去參與幾多次社運，雖然不見得都是拿麥克風的場控，但以工作人員、參與者的角度也有一些經驗，因此可以看出一些問題。」
# 「當天現場真的很亂，我到的時候看到八六（洪崇晏）在那邊拿著大聲公指揮，滿頭大汗，但麥克風可能有問題，很小聲，後面都聽不到。我就打給司改會的朋友借大聲公。」
# 「我那時候沒有吃晚餐，肚子超級餓，感覺場面控制住後，就想說去吃一下司改會朋友帶給我的麵包，轉到轉角發現一群人在追一個人，想說「現在是要打他嗎」，就上前希望雙方冷靜釐清問題，後來的狀況就如同影片。」
# 「表達訴求盡量不要有肢體的衝突。當天大家的目標是要抗議集會遊行法有很多問題，在現場發生衝突對達成這個目標沒有幫助。」
# 「我認為衝突當時一定要先讓在場的所有人了解發生甚麼事，得到完整資訊後，大家可以對這件事有所評價、行為，要是你得到充分資訊之後，還是覺得現非打他不可的話，我也沒辦法，但大家要各自承擔法律責任。」
#
# 【進入立法院的話，想先推動什麼？】
# 「如果順利進入立法院，勞工權益的保障是我會優先處理的，現行的勞基法還有很多可以再改進的地方。另外有些改善勞動條件的方式甚至不需要大費周章修改法條，像是調升基本工資透過審議委員會就可以進行、主管機關也可以自己增加勞動檢查員，這都是立委可以去要求的。」
# 「要想辦法讓臺灣的勞工團結，具體來說就是要營造讓工會組織發展的有利條件。現在台灣的勞工大都很不滿，但是沒有團結發聲、向資方爭取權益的管道。現在的法規讓組工會的門檻太高、對工會會員的保障也不足，很多人因為擔心『棒打出頭鳥』而不敢加入工會。」
# 「工會和資方協商的力量也不夠對等，罷工的條件太高，沒有跟資方協商的籌碼。這些都是政府應該透過政策改善的，降低組工會的門檻，讓工會會員得到更多保障，提升勞工加入工會的意願，並讓工會有可以有更多和資方談判的籌碼。蓬勃發展的工會是改善勞動條件很重要的關鍵。」
# 「另外，基本薪資的調高對臺灣的長遠發展來說是很重要的，短期來看對企業會有所有衝擊，有些大企業因為員工多，會增加不小負擔，但長遠來看，台灣薪資可以一直這麼低嗎？」
# 「婚姻平權是可以馬上做的，技術上不會很困難。臺灣目前面臨憲政正當性的危機，憲政改革必須盡快處理的，它比較困難，因為有公民複決，門檻很高，但這是非常重要的事情，必須要趕快做。另外我自己的專長是司法改革，這方面也有很多事情可以做。不只是刑事，民事、行政、司法體系及人事的改革都是我會很關心的部分。」
# 「如果我今天進了立法院，我也不會提出「現在、馬上廢除死刑」，即使可能全臺灣都知道我是一個堅定的廢死者，但事情不是這樣推動的。真心要推動一件事不能把它當作自我標榜、滿足的口號，而是要去想它需要怎麼實現。」
#
# 【妳看到文山區所面臨的問題？】
# 「這幾年台北市的都更很熱門，但建商卻對文山區興趣缺缺。文山區的房子其實都算老舊，未必能符合居住者的需求，像我母親就很焦慮我們現在住的老公寓沒有電梯，老年生活會很不方便。但要解決這些問題，拆除重建未必是好事，對很多年長者來說，拆除重建要搬家，之後要再搬回來是很痛苦的。」
# 「面對這些屋齡比較久的住宅，我們也可以思考用輔具來改善，技術現在都有，但大家要裝的話都要自己想辦法，我覺得這是政府可以透過政策協助的。」
# 「政治人物要提出舊有的問題很容易，像是大家都希望遷走變電所、批評捷運南環段一直跳票，只要在當地生活久了，這是大家都能提出的問題。」
# 「但我要做的是提出新的政治議程，新的產品，像是勞動條件改善、年金改革，社會分配這些事情，要讓民眾知道這些是需要被注意的，而且是可以透過選舉、政治改善的。」
#
# 【對於其他候選人的看法？】
# （對國民黨籍擬參選人賴士葆）
# 「國民黨的人有兩種，一種是為了利益可以跳來跳去，賴委員則是另一種比較堅定的。好像有人主張統一是為了在中國的生意，有人則是真的相信統一會更好。賴委員反同婚就很堅定，一路反到底，不會見風轉舵，這也是他的優點。」
# 「今天我出來競選，不是因為賴委員是一個壞人所以出來挑戰他，而是他在立法院的所作所為都是為了黨意，選民要的不是一個只會執行黨意志的機器人，我們要的是一個能衡量公平正義的民意代表。」
# 「賴委員2015年說『亞投行跟服貿不一樣，服貿簽訂時我們甚麼都不了解』，但他在2013卻說『服貿對台灣只有好處沒有壞處』，從這矛盾的發言就可以看出來他很忠實在貫徹黨意，這也是他的優點，對黨很忠誠。但選民要的可能不是這樣的立委，而是要對憲法、選民忠誠的民意代表。」
# （對無黨籍擬參選人李慶元）
# 「李慶元的脫黨參選可能凸顯的是國民黨黨內的民主機制出了問題。我們有時候會在拜票場合遇到，如果這次選舉是李慶元代表國民黨出來選，也許會更好。」
# （對樹黨參選人潘翰聲）
# 「潘翰聲是綠黨的前輩，之後另外成立樹黨，這次也以樹黨的身分參選，相信也是有自己的想法。畢竟他也經營選與很久了，只是之前都是在信義松山選區。」
# 「我不認為潘翰聲跟我的政治光譜類似，社民黨的政見比較多元，不單只有環保，還有年金改革等等，產品定位有一定的差距。」
#
# 「我相信社民黨的政見，對於真正關注臺灣前途的人而言都會支持。現在的問題是，很多人還不知道社民黨的存在，也不曉得社民黨的候選人。大多數政治人物是你了解他們越多，就幻滅了，但社民黨的情況相反，只要你越了解我們，就會越願意支持我們。」
# 本文經授權轉載自沃草－國會無雙：人物誌》淡定面對「廢死、同志」標籤—苗博雅青年政治之路
# 看更多！請加入自由評論網粉絲團

# %%
# print soup2.select('.content h2')[0].text
# print soup2.select('.content h1')
print soup2.select('#newstext span')
# for p in soup2.select('#newstext p'):
#     text = p.text
#     print text
# Out:
# []

# %%
s = 'http://news.ltn.com.tw/news/opinion/breakingnews/1474224'
s1 = 'http://news.ltn.com.tw/news/life/paper/923974'
import re
d = re.search("opinion",s1)
print d
# Out:
# None

# %%
if d.group(0) is not None:
    print "not null"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-5c6daf225133> in <module>()
# ----> 1 if d.group(0) is not None:
#       2     print "not null"
#       3
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
#抓到長這樣   /news/opinion/breakingnews/1474224
#點進去長這樣 http://talk.ltn.com.tw/article/breakingnews/1474224
#http://talk.ltn.com.tw/article/ + breakingnews/1474224
#http://news.ltn.com.tw/news/life/paper/923974
#/news/consumer/paper/924314
#http://news.ltn.com.tw/news/consumer/paper/924314
import re

s1 = '/news/opinion/breakingnews/1474224'
# s2 = '/news/life/paper/923974'
if 'opinion' in s1:
     s1
ary = []
ary.append(s1)
ary.append(s2)
trap = 'http://talk.ltn.com.tw/article/'
# Out:
# /news/opinion/breakingnews/1474224

# %%
trap = 'http://talk.ltn.com.tw/article/'
normal = 'http://news.ltn.com.tw'
for aaa in ary:
    if 'opinion' in aaa:
        ddd =  aaa.split('/')
        opinionlink = trap + '/'.join(ddd[3:5])
        print opinionlink
    else:
        print normal + aaa
# Out:
# http://talk.ltn.com.tw/article/breakingnews/1474224
# http://news.ltn.com.tw/news/life/paper/923974

# %% [markdown]
# ----------------------------------2015/10/29----------------------------------(The Latest One)

# %%
#編制PK
def getpk(arry):
    global pk
    for elelink in arry:
        num = str(pkcount)
        if pkcount < 10:
            num = str(0) * 4 + num
        elif pkcount < 100:     
            num = str(0) * 3 + num
        elif pkcount < 1000:     
            num = str(0) * 2 + num
        elif pkcount < 10000:     
            num = str(0) * 1 + num
        pk = ltn + num
        links = {'link':'','area':area,'page':page,'count':count,'pk':pk} #links = {'link':link,'area':area,'page':page,'count':count,'pk':pk}

# %%
# 儲存新聞連結+pk
def getlink(script):
    global arry, pkcount, ltn, pk  #global arry ,pkcount, ltn
    global count
    arry = []  #arry = []
    ltn = 'ltn'   # ltn = 'ltn'
    normal = 'http://news.ltn.com.tw'
    abnormal = 'http://talk.ltn.com.tw/article/'
    soup = BeautifulSoup(res.text)
    for a_tag in soup.select('#newslistul a'):
        a_tag = a_tag.get('href')
        if "opinion" in a_tag:
            sp_link =  a_tag.split('/')
            link = abnormal + '/'.join(sp_link[3:5])
            arry.append(link)   #arry.append(link)
            getpk(arry)             #getpk()
            links = {'link':link,'area':area,'page':page,'count':count,'pk':pk}  #,'pk':pk
            linkary.append(links)
            count +=1
            pkcount += 1    #pkcount += 1
        else:
            link = normal + a_tag
            arry.append(link)  #arry.append(link)
            getpk(arry)            #getpk()
            links = {'link':link,'area':area,'page':page,'count':count,'pk':pk}  #,'pk':pk
            linkary.append(links)
            count +=1
            pkcount += 1    #pkcount += 1

# %%
#選取時間範圍+pk
def timeRange():
    dt = datetime.datetime.now()
    timeroom = {'S_Year':'','S_Month':'','S_Day':'','E_Year':'','E_Month':'','E_Day':''}
    global s_year, s_month, s_day, e_year, e_month, e_day
    e_year = dt.year
    e_month = dt.month
    e_day = dt.day
    
    if e_month == 1:
        s_year = e_year - (1)
        s_month = 10
        s_day = e_day
    elif e_month == 2:
        s_year = e_year - (1)
        s_month = 11
        s_day = e_day - (3)
    elif e_month == 3:
        s_year = e_year - (1)
        s_month = 12
        s_day = e_day
    elif e_month > 3:
        s_year = e_year
        s_month = e_month - (3)
        s_day = e_day
    s_year = str(s_year)
    s_month = str(s_month)
    s_day = str(s_day)
    e_year = str(dt.year)
    e_month = str(dt.month)
    e_day = str(dt.day)
        
    timeroom = {'S_Year':s_year,'S_Month':s_month,'S_Day':s_day,'E_Year':e_year,'E_Month':e_month,'E_Day':e_day}

# %%
import requests
import time
import datetime
from bs4 import BeautifulSoup

timeRange()

#12個行政區['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
ary = ['中正區','大同區','中山區','松山區','大安區','萬華區','信義區','士林區','北投區','內湖區','南港區','文山區']
links = {'link':'','area':'','page':'','count':'','pk':''}
linkary =[]

headers = {
    'Host':'news.ltn.com.tw',
    'Referer':'http://news.ltn.com.tw/search',
    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
}

pkcount = 1    # pkcount = 1
for area in ary:
    count = 1
    for page in range(1,11):
        url_format = 'http://news.ltn.com.tw/search?page={}&keyword='+ area +'&conditions=and&SYear='\
                     + s_year +'&SMonth='+ s_month +'&SDay='+ s_day +'&EYear='+ e_year +'&EMonth='\
                     + e_month +'&EDay='+ e_day
        url_page = url_format.format(page)
        res = requests.get(url_page,headers=headers)
        time.sleep(5)
        script = res.text
        getlink(script)
# Out:
# c:\python27\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "html.parser")
#
#   markup_type=markup_type))

# %%
#新聞連結資訊進入DataFrame
import pandas
data1 = pandas.DataFrame(linkary)
data1
# Out:
#      area  count                                               link  page  \
# 0     中正區      1  http://news.ltn.com.tw/news/society/breakingne...     1
# 1     中正區      2  http://news.ltn.com.tw/news/politics/breakingn...     1
# 2     中正區      3     http://news.ltn.com.tw/news/local/paper/928054     1
# 3     中正區      4  http://news.ltn.com.tw/news/politics/breakingn...     1
# 1428  文山區    137  http://news.ltn.com.tw/news/politics/paper/907114    10
# 1429  文山區    138  http://news.ltn.com.tw/news/consumer/paper/906742    10
# 1430  文山區    139  http://news.ltn.com.tw/news/politics/breakingn...    10
# 1431  文山區    140   http://news.ltn.com.tw/news/society/paper/906576    10
# 1432  文山區    141  http://news.ltn.com.tw/news/society/breakingne...    10
# 1433  文山區    142  http://news.ltn.com.tw/news/society/breakingne...    10
# 1434  文山區    143  http://news.ltn.com.tw/news/society/breakingne...    10
# 1435  文山區    144  http://news.ltn.com.tw/news/business/breakingn...    10
# 1436  文山區    145     http://news.ltn.com.tw/news/local/paper/906315    10
# 1437  文山區    146     http://news.ltn.com.tw/news/local/paper/905660    10
# 1438  文山區    147  http://news.ltn.com.tw/news/society/breakingne...    10
# 1439  文山區    148     http://news.ltn.com.tw/news/local/paper/905381    10
# 1440  文山區    149  http://news.ltn.com.tw/news/life/breakingnews/...    10
# 1441  文山區    150  http://news.ltn.com.tw/news/life/breakingnews/...    10
#
#             pk
# 0     ltn00001
# 1     ltn00002
# 2     ltn00003
# 3     ltn00004
# 4     ltn00005
# 5     ltn00006
# 6     ltn00007
# 7     ltn00008
# 8     ltn00009
# 9     ltn00010
# 10    ltn00011
# 11    ltn00012
# 12    ltn00013
# 13    ltn00014
# 14    ltn00015
# 15    ltn00016
# 16    ltn00017
# 17    ltn00018
# 18    ltn00019
# 19    ltn00020
# 20    ltn00021
# 21    ltn00022
# 22    ltn00023
# 23    ltn00024
# 24    ltn00025
# 25    ltn00026
# 26    ltn00027
# 27    ltn00028
# 28    ltn00029
# 29    ltn00030
# ...        ...
# 1412  ltn01413
# 1413  ltn01414
# 1414  ltn01415
# 1415  ltn01416
# 1416  ltn01417
# 1417  ltn01418
# 1418  ltn01419
# 1419  ltn01420
# 1420  ltn01421
# 1421  ltn01422
# 1422  ltn01423
# 1423  ltn01424
# 1424  ltn01425
# 1425  ltn01426
# 1426  ltn01427
# 1427  ltn01428
# 1428  ltn01429
# 1429  ltn01430
# 1430  ltn01431
# 1431  ltn01432
# 1432  ltn01433
# 1433  ltn01434
# 1434  ltn01435
# 1435  ltn01436
# 1436  ltn01437
# 1437  ltn01438
# 1438  ltn01439
# 1439  ltn01440
# 1440  ltn01441
# 1441  ltn01442
#
# [1442 rows x 5 columns]

# %%
#輸出成CSV檔將連結存起 假如需要可以讀回
data1.to_csv('ltn_link.csv',encode='utf-8')

# %%
#讀回程式
import csv
linkary = []
with open('ltn_link.csv') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        linkary.append(row)

# %%
#抓取新聞內文 (新版)
import requests
import time
from bs4 import BeautifulSoup
headers = {
   'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
}

for ele in linkary:
    url = ele['link']
    text = ''
    if "talk.ltn.com" in url:
        while True:
            try:
                res = requests.get(url,headers = headers)
                res.text
                soup = BeautifulSoup(res.text)
                break
            except:
                time.sleep(5)
        try:
            ele['title'] = soup.select('.conbox h2')[0].text
            ele['date'] = soup.select('.conbox span')[1].text
            for p_tag in soup.select('.cont p'):
                text += p_tag.text.strip()
            ele['content'] = text
        except:
            print "This link has some problems!"
            print ele['link'], ele['area'], ele['count']
    elif "entertainment" in url:
        while True:
            try:
                res = requests.get(url,headers = headers)
                res.text
                soup = BeautifulSoup(res.text)
                break
            except:
                time.sleep(5)
        try:
            ele['title'] = soup.select('.news_content h1')[0].text
            ele['date'] = soup.select('.news_content .date')[0].text
            for p_tag in soup.select('.news_content p'):
                text += p_tag.text.strip()
            ele['content'] = text
        except:
            print "This link has some problems!"
            print ele['link'], ele['area'], ele['count']
    else:
        while True:
            try:
                res = requests.get(url,headers = headers)
                res.text
                soup = BeautifulSoup(res.text)
                break
            except:
                time.sleep(5)
        try:
            ele['title'] = soup.select('.content h1')[0].text
            ele['date'] = soup.select('#newstext span')[0].text
            for p_tag in soup.select('#newstext p'):
                text += p_tag.text
            ele['content'] = text
        except:
            print "This link has some problems!"
            print ele['link'], ele['area'], ele['count']
# Out:
# This link has some problems!
# http://talk.ltn.com.tw/article/paper/917841 大同區 28
# This link has some problems!
# http://talk.ltn.com.tw/article/paper/912279 大同區 50
# This link has some problems!
# http://news.ltn.com.tw/news/sports/breakingnews/1401954 士林區 87
# This link has some problems!
# http://news.ltn.com.tw/news/sports/breakingnews/1401641 士林區 88
# This link has some problems!
# http://news.ltn.com.tw/news/sports/paper/903822 士林區 91
# This link has some problems!
# http://talk.ltn.com.tw/article/paper/907386 內湖區 74

# %%
# #抓取新聞內文 (舊版)
# import requests
# import time
# from bs4 import BeautifulSoup
# headers = {
#    'User-Agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.80 Safari/537.36'
# }

# for ele in linkary:
#     url = ele['link']
#     text = ''
#     while True:
#         try:
#             res = requests.get(url,headers = headers)
#             res.text
#             soup = BeautifulSoup(res.text)
#             break
#         except:
#             time.sleep(5)

#     try:
#         if soup.select('.content h1')[0] is not None:
#             ele['title'] = soup.select('.content h1')[0].text.strip()
#             ele['data'] = soup.select('#newstext span')[0].text
#             for p_tag in soup.select('#newstext p'):
#                 text += p_tag.text.strip()
#             ele['content'] = text
            
# #         elif soup.select('.content h1')[0] is None:
# #             ele['title'] = soup.select('.conbox h2')[0].text.strip()
# #             ele['data'] = soup.select('.writer span')[1].text
# #             for p_tag in soup.select('.cont p'):
# #                 text += p_tag.text.strip()
# #             ele['content'] = text

#         elif soup.select('.conbox h2')[0] is not None:
#             ele['title'] = soup.select('.conbox h2')[0].text.strip()
#             ele['data'] = soup.select('.writer span')[1].text
#             for p_tag in soup.select('.cont p'):
#                 text += p_tag.text.strip()
#             ele['content'] = text
            
#         elif soup.select('.news_content h1')[0] is not None:
#             ele['title'] = soup.select('.news_content h1')[0].text.strip()
#             ele['date'] = soup.select('.news_content .date')[0].text
#             for p_tag in soup.select('.news_content p'):
#                 text += p_tag.text.strip()
#             ele['content'] = text
        
#     except:
#         print "This link has some problems!"
#         print ele['link'], ele['area'], ele['count']
# Out:
# This link has some problems!
# http://talk.ltn.com.tw/article/breakingnews/1474224 中正區 24
# This link has some problems!
# http://talk.ltn.com.tw/article/paper/917841 大同區 27
# This link has some problems!
# http://talk.ltn.com.tw/article/paper/912279 大同區 49
# This link has some problems!
# http://talk.ltn.com.tw/article/breakingnews/1409601 大同區 71
# This link has some problems!
# http://talk.ltn.com.tw/article/breakingnews/1487440 中山區 14
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1467631 中山區 39
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1467631 松山區 21
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1438618 松山區 57
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1435655 松山區 60
# This link has some problems!
# http://talk.ltn.com.tw/article/breakingnews/1432994 松山區 66
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1467641 大安區 40
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1461540 大安區 56
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/paper/919854 大安區 57
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1461276 大安區 58
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1460388 大安區 59
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1471986 萬華區 34
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1464841 萬華區 44
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1460353 萬華區 47
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1438123 萬華區 72
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1489616 信義區 4
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/1486885 信義區 14
# This link has some problems!
# http://news.ltn.com.tw/news/entertainment/breakingnews/
# 22      2  ltn00023                  萬大ONE 近萬大線站點
# 23      2  ltn00024        〈台北都會〉嘉禾新村難全保 柯：不會那麼快拆
# 24      2  ltn00025                《健康充電站》高血壓衛教講座
# 25      2  ltn00026  國會無雙》淡定面對「廢死、同志」標籤：苗博雅青年政治之路
# 26      2  ltn00027              買房竟買到徵收地 他告原屋主勝訴
# 27      2  ltn00028            與超商店員「搏感情」 竟是為了...
# 28      2  ltn00029            國慶日國旗毀損案 嫌犯疑是多位年輕人
# 29      2  ltn00030                  古亭站捷運交會 學區完整
# ...   ...       ...                           ...
# 1412    9  ltn01413       〈台北都會〉防颱啟動 柯：不會喝濁水但可能停水
# 1413    9  ltn01414             知道酒測不會過...他停車轉身就跑
# 1414    9  ltn01415       〈台北都會〉巷弄停車提早收費 龍淵里長質疑標準
# 1415    9  ltn01416            觀光旅遊加持  中正區店面漲幅28%
# 1416    9  ltn01417                   天鵝逼近 最快明發海警
# 1417    9  ltn01418          〈台北都會〉颱風又要來 復舊防災同步作業
# 1418    9  ltn01419                主人不在家 北市府傳淹水災情
# 1419    9  ltn01420               水氣略減少 午後仍有局部雷陣雨
# 1420    9  ltn01421          北市文山區、屏東瑪家鄉 發布一級淹水警戒
# 1421    9  ltn01422         北市南港文山一級淹水警戒  台東大武鄉二級
# 1422    9  ltn01423                  妻被鄰居嫌吵 夫打傷父女
# 1423    9  ltn01424       〈台北都會〉風災樹倒比過去多 柯：復舊沒比較慢
# 1424    9  ltn01425    〈台北都會〉Zoo Mall基地 都發局規劃平價住宿
# 1425    9  ltn01426       偷女鞋聞腳底芬芳「聞鞋癖」偷到歐巴桑的鞋...
# 1426    9  ltn01427         妻深夜騎車回家被嫌吵 丈夫竟揍鄰居女兒胸部
# 1427   10  ltn01428       〈台北都會〉風災一週北市如期復舊 社團號召救樹
# 1428   10  ltn01429             立委選情／親民黨衝政黨票 強攻七席
# 1429   10  ltn01430                文山木新路 公園環繞環境單純
# 1430   10  ltn01431         痛批北市府行動太慢 藍委「自己家園自己清」
# 1431   10  ltn01432                  亂丟垃圾被罰 反告稽查員
# 1432   10  ltn01433               婦人欲輕生 警追蹤手機救回一命
# 1433   10  ltn01434           粗心女錢包掉在公車上 請警即刻攔截成功
# 1434   10  ltn01435              棄置家用垃圾挨罰 男子逆襲稽查員
# 1435   10  ltn01436    業者調查：臥龍街福地宅房價跌最慘 跌幅高達18.5％
# 1436   10  ltn01437      〈台北都會〉主次要幹道搶通 313鄰里公園明清完
# 1437   10  ltn01438              〈台北都會〉校園災損 初估破千萬
# 1438   10  ltn01439             景美溪浮現一男屍 警循證件聯繫家屬
# 1439   10  ltn01440        〈台北都會〉福興路土石流 居民疑遷葬破壞水保
# 1440   10  ltn01441         北市除道路中斷地區外 今晚10時前全數復電
# 1441   10  ltn01442      足感心！移民姐妹載歌載舞下廚做餐 陪長者共餐同樂
#
# [1442 rows x 8 columns]

# %%
#輸出完成品
ltn_ok.to_csv('ltn_ok.csv',encoding='utf-8')

# %% [markdown]
# ------------------------------------------------------------------------------------
